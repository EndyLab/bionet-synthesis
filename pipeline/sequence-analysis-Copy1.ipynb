# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from Bio import SeqIO

# %%
def loadsequencing(file):
    seq = SeqIO.read(file, 'abi')
    
    maxq = np.max(seq.letter_annotations['phred_quality'])
    rolling = pd.Series(seq.letter_annotations['phred_quality']).rolling(window=20).mean()
    start = (rolling > maxq * 0.9).idxmax()
    end = (rolling > maxq * 0.9)[::-1].idxmax()
    
    return seq.seq[start:end], seq, start, end, np.mean(seq.letter_annotations['phred_quality'][start:end])

# %%
plt.plot(seq.letter_annotations['phred_quality'])
plt.plot(pd.Series(seq.letter_annotations['phred_quality']).rolling(window=20).mean())
plt.axvline(x=start, c='g')
plt.axvline(x=end, c='r')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-1575cfc5200c> in <module>()
# ----> 1 plt.plot(seq.letter_annotations['phred_quality'])
#       2 plt.plot(pd.Series(seq.letter_annotations['phred_quality']).rolling(window=20).mean())
#       3 plt.axvline(x=start, c='g')
#       4 plt.axvline(x=end, c='r')
#
# NameError: name 'seq' is not defined

# %%
SYNTH_DIRECTORY = "../synth1/"
BUILD_DIRECTORY = SYNTH_DIRECTORY + "builds/build-1/"

# %%
validation = []
twist = pd.read_csv('../synth1/backup/fragments.csv')

fragments = pd.DataFrame({
    'Gene': twist['Sequence ID'].str.rsplit('_', n=1).str[0],
    'Fragment': twist['Sequence ID'].str.rsplit('_', n=1).str[1],
    'Sequence': twist['Insert Sequence']
})

# Process single gene fragments
for i, gene in fragments[~fragments['Gene'].str.contains('_link_')].groupby('Gene'):
    frags = []
    for seq in gene['Sequence'].str.upper():
        # Virtual digest using BbsI
        seq = seq[seq.find('GAAGAC')+8:]
        seq = seq[:seq.find('GTCTTC')-2]
        frags.append(seq)

    # Now we have a list of 'digested' fragments; assemble them based on overlaps.
    while len(frags) > 1:
        frag = frags.pop(0)
        for other in frags:
            if other[-4:] == frag[:4]:
                frag = other[:-4] + frag
                frags.remove(other)
                break
        frags.append(frag)

    # Add assembled full sequence to the validation database
    # Remove the first and last nucleotides to get the CDS instead of MoClo adapters
    validation.append({'Gene': gene['Gene'].iloc[0], 'Sequence': frags[0][1:-1]})

# Process multigene fragments
for i, gene in fragments[fragments['Gene'].str.contains('_link_')].iterrows():
    names = gene['Gene'].split('_link_')

    # Virtual digest using BbsI
    seq = gene['Sequence'].upper()
    seq = seq[seq.find('GAAGAC')+8:]
    seq = seq[:seq.find('GTCTTC')-2]
    validation.append({'Gene': names[0], 'Sequence': seq[1:-1]})

    # We have a multi-gene fragment, digest with BtgZI
    seq = gene['Sequence'].upper()
    seq = seq[seq.find('GCGATG')+16:]
    seq = seq[:seq.find('CATCGC')-10]
    validation.append({'Gene': names[1], 'Sequence': seq[1:-1]})
    
validation_dna = pd.DataFrame(validation)

# %%
validation_dna.to_csv(SYNTH_DIRECTORY + "optimized.csv")

# %%
import glob
import os
import re

from Bio import pairwise2
from Bio import AlignIO
from Bio import Align
from Bio import Seq
from Bio import SeqRecord
from Bio.Alphabet import generic_dna

forward_primer = "M13-Forward---20-"
reverse_primer = "M13-Reverse"

all_alignments = []
bad_alignments = []
good_name = []
good_well = []

rfp_name = []
rfp_well = []

good = 0
rfp = 0

backbone_seq = SeqIO.read('./popen_v1-1_backbone.fasta', 'fasta')
backbone_seq = backbone_seq.seq

for seqfile in glob.glob(BUILD_DIRECTORY + "sequencing/*{}*.ab1".format(forward_primer)):
    
    goodF = 0
    goodR = 0
    rfpF = 0
    rfpR = 0

    print("Analysing sequence", seqfile)
    
    initials, order_number, plate_number, well_number, sample_name, primer_name, well_address = re.match(
        r'.*/([A-Z]+)_([0-9]+)-([0-9])([0-9]+)_([A-Za-z0-9_-]+)_([A-Za-z0-9-]+)_([A-H][0-9]{2}).ab1',
        seqfile).groups()
    revfile = "{}/{}_{}-{}{}_{}_{}_{}.ab1".format(os.path.dirname(seqfile), initials, order_number, (int(plate_number)+1), well_number, sample_name, reverse_primer, well_address)
    
    print("Validating {} ({}-{})".format(sample_name, plate_number, well_address))
    
    # We assume that for every forward there is a reverse
    forward, _, _, _, forward_qual = loadsequencing(seqfile)
    reverse, revseq, _, _, reverse_qual = loadsequencing(revfile)
    
    print("Quality", forward_qual, reverse_qual)
    
#     sample_name = re.sub(r'-*(.*)_[0-9]+', r'\1', sample_name)
    if "link" in sample_name:
        sample_name = re.sub(r'(.*)_link_.*', r'\1', sample_name)
        
    target_seq = validation_dna.loc[validation_dna['Gene']==sample_name, 'Sequence'].iloc[0]
        
    forward_untrim = forward
    reverse_untrim = reverse.reverse_complement()
    
    forward = forward[forward.find('ATG'):] # Start at start codon
    reverse = reverse[reverse.find('TCA'):].reverse_complement() # Stop at stop    
    
    forward_align = pairwise2.align.globalxx(target_seq, forward, one_alignment_only=True)
    reverse_align = pairwise2.align.globalxx(target_seq, reverse, one_alignment_only=True)
    
    if len(forward_align) == 0 or len(reverse_align) == 0:
        if len(forward_align) == 0:
            print("Forward doesn't align")

        if len(reverse_align) == 0:
            print("Reverse doesn't align")
            
        continue
    
    forward_align = forward_align[0]
    reverse_align = reverse_align[0]
    
    if (forward_align[2] != min(len(forward), len(target_seq))):
        print("Forward doesn't match gene: scores are {} and {}".format(forward_align[2],len(forward)))
        forward_align_back = pairwise2.align.globalxx(backbone_seq, forward_untrim, one_alignment_only=True)
        forward_align_back = forward_align_back[0]
        
        if (forward_align_back[2] == min(len(forward_untrim), len(backbone_seq))):
            print("Forward aligns to backbone: scores are {} and {}".format(forward_align_back[2],len(forward_untrim)))
            rfpF = rfpF + 1
        else:
            print("Forward doesn't align to backbone: scores are {} and {}".format(forward_align_back[2],len(forward_untrim)))
            
        align = Align.MultipleSeqAlignment([
            SeqRecord.SeqRecord(Seq.Seq(forward_align[0], generic_dna), id="TargetSequence"),
            SeqRecord.SeqRecord(Seq.Seq(forward_align[1], generic_dna), id="ForwardSequence"),
        ])
        bad_alignments.append(align)
    else:
        print("Forward matches gene: scores are {} and {}".format(forward_align[2],len(forward)))
        goodF = goodF + 1
        
    if (reverse_align[2] != min(len(reverse), len(target_seq))):
        print("Reverse doesn't match gene: scores are {} and {}".format(reverse_align[2],len(reverse)))
        reverse_align_back = pairwise2.align.globalxx(backbone_seq, reverse_untrim, one_alignment_only=True)
        reverse_align_back = reverse_align_back[0]

        if (reverse_align_back[2] == min(len(reverse_untrim), len(backbone_seq))):
            print("Reverse aligns to backbone: scores are {} and {}".format(reverse_align_back[2],len(reverse_untrim)))
            rfpR = 1
        else:
            print("Reverse doesn't align to backbone: scores are {} and {}".format(reverse_align_back[2],len(reverse_untrim)))            
        align = Align.MultipleSeqAlignment([
            SeqRecord.SeqRecord(Seq.Seq(reverse_align[0], generic_dna), id="TargetSequence"),
            SeqRecord.SeqRecord(Seq.Seq(reverse_align[1], generic_dna), id="ReverseSequence"),
        ])
        bad_alignments.append(align)
    else:
        print("Reverse matches gene: scores are {} and {}".format(reverse_align[2],len(reverse)))
        goodR = 1
    
    if goodF + goodR == 2:
        good = good + 1
        print(good)
        good_name.append(sample_name)
        good_well.append(well_address)
    if rfpF + rfpR == 2:
        rfp = rfp + 1
        print(rfp)
        rfp_name.append(sample_name)
        rfp_well.append(well_address)

    print()

print("good", good)
print("rfp",rfp)
good = pd.DataFrame({'Gene': good_name,
                     'Well': good_well})

rfp = pd.DataFrame({'Gene': rfp_name,
                    'Well': rfp_well})

AlignIO.write(bad_alignments, BUILD_DIRECTORY + 'bad-alignments.aln'.format(initials, order_number), 'clustal')
# Out:
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1001_MMSYN1_0115_M13-Forward---20-_A01.ab1
# Validating MMSYN1_0115 (1-A01)
# Quality 60.0085034014 60.8630952381
# Forward matches gene: scores are 542.0 and 542
# Reverse matches gene: scores are 475.0 and 475
# 1
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1002_MMSYN1_0511_M13-Forward---20-_B01.ab1
# Validating MMSYN1_0511 (1-B01)
# Quality 60.3409893993 59.5457685665
# Forward doesn't match gene: scores are 354.0 and 520
# Forward aligns to backbone: scores are 566.0 and 566
# Reverse doesn't match gene: scores are 370.0 and 540
# Reverse aligns to backbone: scores are 579.0 and 579
# 1
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1003_MMSYN1_0215_M13-Forward---20-_C01.ab1
# Validating MMSYN1_0215 (1-C01)
# Quality 60.3360128617 60.423670669
# Forward doesn't match gene: scores are 313.0 and 572
# Forward aligns to backbone: scores are 622.0 and 622
# Reverse doesn't match gene: scores are 311.0 and 540
# Reverse aligns to backbone: scores are 583.0 and 583
# 2
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1004_MMSYN1_0693_M13-Forward---20-_D01.ab1
# Validating MMSYN1_0693 (1-D01)
# Quality 58.6042345277 59.0018315018
# Forward matches gene: scores are 562.0 and 562
# Reverse matches gene: scores are 502.0 and 502
# 2
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1005_MMSYN1_0107_M13-Forward---20-_E01.ab1
# Validating MMSYN1_0107 (1-E01)
# Quality 59.2717770035 58.25
# Forward doesn't match gene: scores are 287.0 and 524
# Forward aligns to backbone: scores are 574.0 and 574
# Reverse doesn't match gene: scores are 286.0 and 524
# Reverse aligns to backbone: scores are 564.0 and 564
# 3
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1006_MMSYN1_0148_M13-Forward---20-_F01.ab1
# Validating MMSYN1_0148 (1-F01)
# Quality 58.0346083789 57.5088339223
# Forward doesn't match gene: scores are 292.0 and 500
# Forward aligns to backbone: scores are 549.0 and 549
# Reverse doesn't match gene: scores are 303.0 and 525
# Reverse aligns to backbone: scores are 566.0 and 566
# 4
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1007_MMSYN1_0494_M13-Forward---20-_G01.ab1
# Validating MMSYN1_0494 (1-G01)
# Quality 60.5993208829 59.8283464567
# Forward doesn't match gene: scores are 382.0 and 539
# Forward aligns to backbone: scores are 589.0 and 589
# Reverse doesn't match gene: scores are 411.0 and 597
# Reverse aligns to backbone: scores are 635.0 and 635
# 5
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1008_MMSYN1_0696_M13-Forward---20-_H01.ab1
# Validating MMSYN1_0696 (1-H01)
# Quality 60.6040955631 60.2552504039
# Forward doesn't match gene: scores are 391.0 and 536
# Forward aligns to backbone: scores are 586.0 and 586
# Reverse doesn't match gene: scores are 403.0 and 575
# Reverse aligns to backbone: scores are 619.0 and 619
# 6
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1009_MMSYN1_0530_M13-Forward---20-_A02.ab1
# Validating MMSYN1_0530 (1-A02)
# Quality 59.2067226891 58.3322091062
# Forward doesn't match gene: scores are 359.0 and 545
# Forward aligns to backbone: scores are 595.0 and 595
# Reverse doesn't match gene: scores are 365.0 and 550
# Reverse aligns to backbone: scores are 593.0 and 593
# 7
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1010_MMSYN1_0481_M13-Forward---20-_B02.ab1
# Validating MMSYN1_0481 (1-B02)
# Quality 60.2374100719 59.7042735043
# Forward doesn't match gene: scores are 296.0 and 508
# Forward aligns to backbone: scores are 556.0 and 556
# Reverse doesn't match gene: scores are 312.0 and 546
# Reverse aligns to backbone: scores are 585.0 and 585
# 8
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1011_MMSYN1_0907_M13-Forward---20-_C02.ab1
# Validating MMSYN1_0907 (1-C02)
# Quality 60.5031948882 60.6586620926
# Forward doesn't match gene: scores are 427.0 and 576
# Forward aligns to backbone: scores are 626.0 and 626
# Reverse doesn't match gene: scores are 410.0 and 541
# Reverse aligns to backbone: scores are 583.0 and 583
# 9
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1012_MMSYN1_0281_M13-Forward---20-_D02.ab1
# Validating MMSYN1_0281 (1-D02)
# Quality 60.1833910035 60.2904347826
# Forward doesn't match gene: scores are 372.0 and 531
# Forward aligns to backbone: scores are 578.0 and 578
# Reverse doesn't match gene: scores are 376.0 and 535
# Reverse aligns to backbone: scores are 575.0 and 575
# 10
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1013_MMSYN1_0833_M13-Forward---20-_E02.ab1
# Validating MMSYN1_0833 (1-E02)
# Quality 60.1650943396 60.5504761905
# Forward doesn't match gene: scores are 443.0 and 588
# Forward aligns to backbone: scores are 636.0 and 636
# Reverse doesn't match gene: scores are 443.0 and 489
# Reverse aligns to backbone: scores are 525.0 and 525
# 11
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1014_MMSYN1_0346_M13-Forward---20-_F02.ab1
# Validating MMSYN1_0346 (1-F02)
# Quality 60.6404109589 60.0300632911
# Forward matches gene: scores are 534.0 and 534
# Reverse matches gene: scores are 586.0 and 586
# 3
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1015_MMSYN1_0421_M13-Forward---20-_G02.ab1
# Validating MMSYN1_0421 (1-G02)
# Quality 60.4455284553 13.6787709497
# Forward matches gene: scores are 312.0 and 564
# Reverse doesn't match gene: scores are 148.0 and 213
# Reverse doesn't align to backbone: scores are 290.0 and 358
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1016_MMSYN1_0168_M13-Forward---20-_H02.ab1
# Validating MMSYN1_0168 (1-H02)
# Quality 59.9267886855 60.2
# Forward doesn't match gene: scores are 539.0 and 553
# Forward aligns to backbone: scores are 601.0 and 601
# Reverse matches gene: scores are 1.0 and 1
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1017_MMSYN1_0435_M13-Forward---20-_A03.ab1
# Validating MMSYN1_0435 (1-A03)
# Quality 60.3280701754 58.3466334165
# Forward doesn't match gene: scores are 423.0 and 523
# Forward aligns to backbone: scores are 570.0 and 570
# Reverse doesn't match gene: scores are 316.0 and 342
# Reverse aligns to backbone: scores are 401.0 and 401
# 12
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1018_MMSYN1_0253_M13-Forward---20-_B03.ab1
# Validating MMSYN1_0253 (1-B03)
# Quality 60.1634615385 60.1305309735
# Forward doesn't match gene: scores are 332.0 and 572
# Forward aligns to backbone: scores are 624.0 and 624
# Reverse doesn't match gene: scores are 302.0 and 450
# Reverse aligns to backbone: scores are 452.0 and 452
# 13
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1019_MMSYN1_0138_M13-Forward---20-_C03.ab1
# Validating MMSYN1_0138 (1-C03)
# Quality 60.1266025641 59.9664991625
# Forward doesn't match gene: scores are 552.0 and 574
# Forward aligns to backbone: scores are 624.0 and 624
# Reverse doesn't match gene: scores are 552.0 and 568
# Reverse aligns to backbone: scores are 597.0 and 597
# 14
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1020_MMSYN1_0389_M13-Forward---20-_D03.ab1
# Validating MMSYN1_0389 (1-D03)
# Quality 60.4654895666 60.6449275362
# Forward doesn't match gene: scores are 569.0 and 576
# Forward aligns to backbone: scores are 623.0 and 623
# Reverse doesn't match gene: scores are 511.0 and 512
# Reverse aligns to backbone: scores are 552.0 and 552
# 15
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1021_MMSYN1_0039_M13-Forward---20-_E03.ab1
# Validating MMSYN1_0039 (1-E03)
# Quality 60.285942492 60.2948275862
# Forward doesn't match gene: scores are 561.0 and 576
# Forward aligns to backbone: scores are 626.0 and 626
# Reverse doesn't match gene: scores are 534.0 and 541
# Reverse aligns to backbone: scores are 580.0 and 580
# 16
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1022_MMSYN1_0043_M13-Forward---20-_F03.ab1
# Validating MMSYN1_0043 (1-F03)
# Quality 60.285483871 60.6644182125
# Forward matches gene: scores are 573.0 and 573
# Reverse matches gene: scores are 548.0 and 548
# 4
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1023_MMSYN1_0447_M13-Forward---20-_G03.ab1
# Validating MMSYN1_0447 (1-G03)
# Quality 60.1098726115 60.4135702746
# Forward doesn't match gene: scores are 336.0 and 576
# Forward aligns to backbone: scores are 628.0 and 628
# Reverse doesn't match gene: scores are 340.0 and 575
# Reverse aligns to backbone: scores are 619.0 and 619
# 17
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1024_MMSYN1_0045_M13-Forward---20-_H03.ab1
# Validating MMSYN1_0045 (1-H03)
# Quality 53.1596858639 60.424137931
# Forward doesn't match gene: scores are 283.0 and 335
# Forward aligns to backbone: scores are 382.0 and 382
# Reverse doesn't match gene: scores are 372.0 and 540
# Reverse aligns to backbone: scores are 580.0 and 580
# 18
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1025_MMSYN1_0283_M13-Forward---20-_A04.ab1
# Validating MMSYN1_0283 (1-A04)
# Quality 60.498392283 60.1590493601
# Forward doesn't match gene: scores are 376.0 and 576
# Forward aligns to backbone: scores are 622.0 and 622
# Reverse doesn't match gene: scores are 357.0 and 513
# Reverse aligns to backbone: scores are 547.0 and 547
# 19
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1026_MMSYN1_0416_M13-Forward---20-_B04.ab1
# Validating MMSYN1_0416 (1-B04)
# Quality 59.8852988691 60.1032702238
# Forward doesn't match gene: scores are 291.0 and 572
# Forward aligns to backbone: scores are 619.0 and 619
# Reverse doesn't match gene: scores are 286.0 and 541
# Reverse aligns to backbone: scores are 581.0 and 581
# 20
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1027_MMSYN1_0839_M13-Forward---20-_C04.ab1
# Validating MMSYN1_0839 (1-C04)
# Quality 59.7893890675 60.5017857143
# Forward doesn't match gene: scores are 265.0 and 576
# Forward aligns to backbone: scores are 622.0 and 622
# Reverse doesn't match gene: scores are 249.0 and 531
# Reverse aligns to backbone: scores are 560.0 and 560
# 21
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1028_MMSYN1_0686_M13-Forward---20-_D04.ab1
# Validating MMSYN1_0686 (1-D04)
# Quality 60.2854864434 60.7227036395
# Forward matches gene: scores are 575.0 and 575
# Reverse matches gene: scores are 530.0 and 530
# 5
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1029_MMSYN1_0697_M13-Forward---20-_E04.ab1
# Validating MMSYN1_0697 (1-E04)
# Quality 55.4460966543 53.8367346939
# Forward doesn't match gene: scores are 414.0 and 490
# Forward aligns to backbone: scores are 538.0 and 538
# Reverse doesn't match gene: scores are 392.0 and 448
# Reverse aligns to backbone: scores are 490.0 and 490
# 22
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1030_MMSYN1_0286_M13-Forward---20-_F04.ab1
# Validating MMSYN1_0286 (1-F04)
# Quality 60.4830053667 60.0831826401
# Forward doesn't match gene: scores are 398.0 and 512
# Forward aligns to backbone: scores are 559.0 and 559
# Reverse doesn't match gene: scores are 409.0 and 541
# Reverse aligns to backbone: scores are 553.0 and 553
# 23
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1031_MMSYN1_0166_M13-Forward---20-_G04.ab1
# Validating MMSYN1_0166 (1-G04)
# Quality 60.0841423948 60.1899827288
# Forward doesn't match gene: scores are 466.0 and 571
# Forward aligns to backbone: scores are 618.0 and 618
# Reverse doesn't match gene: scores are 450.0 and 539
# Reverse aligns to backbone: scores are 579.0 and 579
# 24
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1032_MMSYN1_0008_M13-Forward---20-_H04.ab1
# Validating MMSYN1_0008 (1-H04)
# Quality 60.4390243902 60.4148020654
# Forward doesn't match gene: scores are 437.0 and 523
# Forward aligns to backbone: scores are 574.0 and 574
# Reverse doesn't match gene: scores are 437.0 and 541
# Reverse aligns to backbone: scores are 581.0 and 581
# 25
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1033_MMSYN1_0838_M13-Forward---20-_A05.ab1
# Validating MMSYN1_0838 (1-A05)
# Quality 60.0779014308 60.1155234657
# Forward doesn't match gene: scores are 416.0 and 582
# Forward aligns to backbone: scores are 629.0 and 629
# Reverse doesn't match gene: scores are 384.0 and 513
# Reverse aligns to backbone: scores are 554.0 and 554
# 26
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1034_MMSYN1_0433_M13-Forward---20-_B05.ab1
# Validating MMSYN1_0433 (1-B05)
# Quality 53.0378787879 56.7211328976
# Forward doesn't match gene: scores are 210.0 and 217
# Forward aligns to backbone: scores are 264.0 and 264
# Reverse doesn't match gene: scores are 358.0 and 453
# Reverse aligns to backbone: scores are 459.0 and 459
# 27
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1035_MMSYN1_0066_M13-Forward---20-_C05.ab1
# Validating MMSYN1_0066 (1-C05)
# Quality 60.0826833073 60.0923824959
# Forward matches gene: scores are 591.0 and 591
# Reverse matches gene: scores are 570.0 and 570
# 6
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1036_MMSYN1_0885_M13-Forward---20-_D05.ab1
# Validating MMSYN1_0885 (1-D05)
# Quality 60.2930153322 60.2104316547
# Forward doesn't match gene: scores are 562.0 and 571
# Forward aligns to backbone: scores are 587.0 and 587
# Reverse doesn't match gene: scores are 515.0 and 518
# Reverse aligns to backbone: scores are 556.0 and 556
# 28
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1037_MMSYN1_0144_M13-Forward---20-_E05.ab1
# Validating MMSYN1_0144 (1-E05)
# Quality 58.9306260575 56.9593495935
# Forward doesn't match gene: scores are 329.0 and 547
# Forward aligns to backbone: scores are 591.0 and 591
# Reverse doesn't match gene: scores are 314.0 and 491
# Reverse aligns to backbone: scores are 492.0 and 492
# 29
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1038_MMSYN1_0326_M13-Forward---20-_F05.ab1
# Validating MMSYN1_0326 (1-F05)
# Quality 60.2256 60.6117850953
# Forward matches gene: scores are 578.0 and 578
# Reverse matches gene: scores are 538.0 and 538
# 7
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1039_MMSYN1_0327_M13-Forward---20-_G05.ab1
# Validating MMSYN1_0327 (1-G05)
# Quality 60.1207729469 58.8525252525
# Forward doesn't match gene: scores are 433.0 and 574
# Forward aligns to backbone: scores are 621.0 and 621
# Reverse doesn't match gene: scores are 392.0 and 487
# Reverse aligns to backbone: scores are 495.0 and 495
# 30
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1040_MMSYN1_0097_M13-Forward---20-_H05.ab1
# Validating MMSYN1_0097 (1-H05)
# Quality 60.4077181208 59.8448275862
# Forward doesn't match gene: scores are 436.0 and 545
# Forward aligns to backbone: scores are 596.0 and 596
# Reverse doesn't match gene: scores are 435.0 and 539
# Reverse aligns to backbone: scores are 580.0 and 580
# 31
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1041_MMSYN1_0108_M13-Forward---20-_A06.ab1
# Validating MMSYN1_0108 (1-A06)
# Quality 59.9069020867 60.4555765595
# Forward doesn't match gene: scores are 479.0 and 576
# Forward aligns to backbone: scores are 623.0 and 623
# Reverse doesn't match gene: scores are 448.0 and 514
# Reverse aligns to backbone: scores are 529.0 and 529
# 32
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1042_MMSYN1_0503_M13-Forward---20-_B06.ab1
# Validating MMSYN1_0503 (1-B06)
# Quality 60.4222222222 60.2714025501
# Forward doesn't match gene: scores are 299.0 and 583
# Forward aligns to backbone: scores are 630.0 and 630
# Reverse doesn't match gene: scores are 290.0 and 513
# Reverse aligns to backbone: scores are 549.0 and 549
# 33
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1043_MMSYN1_0077_M13-Forward---20-_C06.ab1
# Validating MMSYN1_0077 (1-C06)
# Quality 60.151799687 60.5487804878
# Forward matches gene: scores are 592.0 and 592
# Reverse matches gene: scores are 530.0 and 530
# 8
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1044_MMSYN1_0859_M13-Forward---20-_D06.ab1
# Validating MMSYN1_0859 (1-D06)
# Quality 59.1177446103 57.5010526316
# Forward doesn't match gene: scores are 564.0 and 568
# Forward aligns to backbone: scores are 603.0 and 603
# Reverse matches gene: scores are 446.0 and 446
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1045_MMSYN1_0817_M13-Forward---20-_E06.ab1
# Validating MMSYN1_0817 (1-E06)
# Quality 60.2907915994 59.9293103448
# Forward doesn't match gene: scores are 458.0 and 572
# Forward aligns to backbone: scores are 619.0 and 619
# Reverse doesn't match gene: scores are 440.0 and 540
# Reverse aligns to backbone: scores are 580.0 and 580
# 34
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1046_MMSYN1_0853_M13-Forward---20-_F06.ab1
# Validating MMSYN1_0853 (1-F06)
# Quality 59.8056379822 60.1885098743
# Forward doesn't match gene: scores are 428.0 and 628
# Forward aligns to backbone: scores are 674.0 and 674
# Reverse doesn't match gene: scores are 382.0 and 517
# Reverse aligns to backbone: scores are 557.0 and 557
# 35
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1047_MMSYN1_0302_M13-Forward---20-_G06.ab1
# Validating MMSYN1_0302 (1-G06)
# Quality 59.9919224556 58.6724470135
# Forward doesn't match gene: scores are 395.0 and 572
# Forward aligns to backbone: scores are 619.0 and 619
# Reverse doesn't match gene: scores are 368.0 and 511
# Reverse aligns to backbone: scores are 519.0 and 519
# 36
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1048_MMSYN1_0614_M13-Forward---20-_H06.ab1
# Validating MMSYN1_0614 (1-H06)
# Quality 60.2656 60.1256454389
# Forward doesn't match gene: scores are 481.0 and 574
# Forward aligns to backbone: scores are 625.0 and 625
# Reverse doesn't match gene: scores are 459.0 and 541
# Reverse aligns to backbone: scores are 581.0 and 581
# 37
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1049_MMSYN1_0440_M13-Forward---20-_A07.ab1
# Validating MMSYN1_0440 (1-A07)
# Quality 59.5190082645 60.2990990991
# Forward matches gene: scores are 558.0 and 558
# Reverse matches gene: scores are 512.0 and 512
# 9
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1050_MMSYN1_0388_M13-Forward---20-_B07.ab1
# Validating MMSYN1_0388 (1-B07)
# Quality 60.2936630603 60.1894736842
# Forward doesn't match gene: scores are 382.0 and 600
# Forward aligns to backbone: scores are 647.0 and 647
# Reverse doesn't match gene: scores are 363.0 and 541
# Reverse aligns to backbone: scores are 570.0 and 570
# 38
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1051_MMSYN1_0906_M13-Forward---20-_C07.ab1
# Validating MMSYN1_0906 (1-C07)
# Quality 60.6557377049 60.8262350937
# Forward matches gene: scores are 563.0 and 563
# Reverse matches gene: scores are 548.0 and 548
# 10
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1052_MMSYN1_0264_M13-Forward---20-_D07.ab1
# Validating MMSYN1_0264 (1-D07)
# Quality 60.1286644951 60.1094890511
# Forward doesn't match gene: scores are 473.0 and 570
# Forward aligns to backbone: scores are 614.0 and 614
# Reverse doesn't match gene: scores are 441.0 and 509
# Reverse aligns to backbone: scores are 548.0 and 548
# 39
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1053_MMSYN1_0352_M13-Forward---20-_E07.ab1
# Validating MMSYN1_0352 (1-E07)
# Quality 60.3017656501 60.4894366197
# Forward doesn't match gene: scores are 355.0 and 576
# Forward aligns to backbone: scores are 623.0 and 623
# Reverse doesn't match gene: scores are 341.0 and 541
# Reverse aligns to backbone: scores are 568.0 and 568
# 40
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1054_MMSYN1_0777_M13-Forward---20-_F07.ab1
# Validating MMSYN1_0777 (1-F07)
# Quality 60.0823909532 59.3902027027
# Forward doesn't match gene: scores are 338.0 and 575
# Forward aligns to backbone: scores are 619.0 and 619
# Reverse doesn't match gene: scores are 334.0 and 563
# Reverse aligns to backbone: scores are 592.0 and 592
# 41
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1055_MMSYN1_0167_M13-Forward---20-_G07.ab1
# Validating MMSYN1_0167 (1-G07)
# Quality 60.2326332795 60.2025316456
# Forward doesn't match gene: scores are 546.0 and 572
# Forward aligns to backbone: scores are 619.0 and 619
# Reverse doesn't match gene: scores are 500.0 and 513
# Reverse aligns to backbone: scores are 553.0 and 553
# 42
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1056_MMSYN1_0505_M13-Forward---20-_H07.ab1
# Validating MMSYN1_0505 (1-H07)
# Quality 60.1107544141 59.9786407767
# Forward doesn't match gene: scores are 474.0 and 574
# Forward aligns to backbone: scores are 623.0 and 623
# Reverse doesn't match gene: scores are 435.0 and 494
# Reverse aligns to backbone: scores are 515.0 and 515
# 43
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1057_MMSYN1_0220_M13-Forward---20-_A08.ab1
# Validating MMSYN1_0220 (1-A08)
# Quality 60.4345047923 59.9064516129
# Forward matches gene: scores are 576.0 and 576
# Reverse matches gene: scores are 579.0 and 579
# 11
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1058_MMSYN1_0672_M13-Forward---20-_B08.ab1
# Validating MMSYN1_0672 (1-B08)
# Quality 59.9433656958 59.8821362799
# Forward doesn't match gene: scores are 257.0 and 568
# Forward aligns to backbone: scores are 618.0 and 618
# Reverse doesn't match gene: scores are 251.0 and 517
# Reverse aligns to backbone: scores are 543.0 and 543
# 44
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1059_MMSYN1_0372_M13-Forward---20-_C08.ab1
# Validating MMSYN1_0372 (1-C08)
# Quality 58.1729200653 59.5217391304
# Forward doesn't match gene: scores are 553.0 and 567
# Forward aligns to backbone: scores are 613.0 and 613
# Reverse doesn't match gene: scores are 511.0 and 518
# Reverse aligns to backbone: scores are 529.0 and 529
# 45
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1060_MMSYN1_0296_M13-Forward---20-_D08.ab1
# Validating MMSYN1_0296 (1-D08)
# Quality 59.281098546 58.1078998073
# Forward doesn't match gene: scores are 374.0 and 572
# Forward aligns to backbone: scores are 619.0 and 619
# Reverse doesn't match gene: scores are 354.0 and 515
# Reverse aligns to backbone: scores are 519.0 and 519
# 46
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1061_MMSYN1_0054_M13-Forward---20-_E08.ab1
# Validating MMSYN1_0054 (1-E08)
# Quality 59.1404958678 57.7198067633
# Forward doesn't match gene: scores are 321.0 and 571
# Forward aligns to backbone: scores are 605.0 and 605
# Reverse doesn't match gene: scores are 273.0 and 412
# Reverse aligns to backbone: scores are 414.0 and 414
# 47
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1062_MMSYN1_0298_M13-Forward---20-_F08.ab1
# Validating MMSYN1_0298 (1-F08)
# Quality 60.1851851852 56.5401301518
# Forward doesn't match gene: scores are 245.0 and 550
# Forward aligns to backbone: scores are 594.0 and 594
# Reverse doesn't match gene: scores are 224.0 and 438
# Reverse aligns to backbone: scores are 461.0 and 461
# 48
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1063_MMSYN1_0139_M13-Forward---20-_G08.ab1
# Validating MMSYN1_0139 (1-G08)
# Quality 59.4407079646 60.9285714286
# Forward doesn't match gene: scores are 528.0 and 529
# Forward aligns to backbone: scores are 565.0 and 565
# Reverse matches gene: scores are 520.0 and 520
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1064_MMSYN1_0270_M13-Forward---20-_H08.ab1
# Validating MMSYN1_0270 (1-H08)
# Quality 60.1227786753 59.9982110912
# Forward doesn't match gene: scores are 302.0 and 573
# Forward aligns to backbone: scores are 619.0 and 619
# Reverse doesn't match gene: scores are 291.0 and 520
# Reverse aligns to backbone: scores are 559.0 and 559
# 49
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1065_MMSYN1_0371_M13-Forward---20-_A09.ab1
# Validating MMSYN1_0371 (1-A09)
# Quality 60.5224913495 59.9036144578
# Forward doesn't match gene: scores are 517.0 and 527
# Forward aligns to backbone: scores are 578.0 and 578
# Reverse doesn't match gene: scores are 530.0 and 541
# Reverse aligns to backbone: scores are 581.0 and 581
# 50
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1066_MMSYN1_0042_M13-Forward---20-_B09.ab1
# Validating MMSYN1_0042 (1-B09)
# Quality 60.4581993569 53.0899470899
# Forward doesn't match gene: scores are 440.0 and 574
# Forward aligns to backbone: scores are 622.0 and 622
# Reverse matches gene: scores are 101.0 and 101
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1067_MMSYN1_0132_M13-Forward---20-_C09.ab1
# Validating MMSYN1_0132 (1-C09)
# Quality 60.249201278 60.6462585034
# Forward doesn't match gene: scores are 474.0 and 576
# Forward aligns to backbone: scores are 626.0 and 626
# Reverse doesn't match gene: scores are 466.0 and 543
# Reverse aligns to backbone: scores are 588.0 and 588
# 51
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1068_MMSYN1_0525_M13-Forward---20-_D09.ab1
# Validating MMSYN1_0525 (1-D09)
# Quality 58.8102836879 55.5428571429
# Forward doesn't match gene: scores are 288.0 and 523
# Forward aligns to backbone: scores are 564.0 and 564
# Reverse doesn't match gene: scores are 269.0 and 444
# Reverse aligns to backbone: scores are 455.0 and 455
# 52
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1069_MMSYN1_0806_M13-Forward---20-_E09.ab1
# Validating MMSYN1_0806 (1-E09)
# Quality 58.5348837209 59.398467433
# Forward doesn't match gene: scores are 279.0 and 521
# Forward aligns to backbone: scores are 559.0 and 559
# Reverse doesn't match gene: scores are 284.0 and 517
# Reverse aligns to backbone: scores are 522.0 and 522
# 53
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1070_MMSYN1_0338_M13-Forward---20-_F09.ab1
# Validating MMSYN1_0338 (1-F09)
# Quality 59.5445859873 58.1513292434
# Forward doesn't match gene: scores are 409.0 and 576
# Forward aligns to backbone: scores are 628.0 and 628
# Reverse doesn't match gene: scores are 357.0 and 460
# Reverse aligns to backbone: scores are 489.0 and 489
# 54
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1071_MMSYN1_0164_M13-Forward---20-_G09.ab1
# Validating MMSYN1_0164 (1-G09)
# Quality 60.4520325203 60.4493996569
# Forward matches gene: scores are 495.0 and 563
# Reverse matches gene: scores are 495.0 and 536
# 12
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1072_MMSYN1_0409_M13-Forward---20-_H09.ab1
# Validating MMSYN1_0409 (1-H09)
# Quality 60.0961538462 59.8793103448
# Forward doesn't match gene: scores are 419.0 and 574
# Forward aligns to backbone: scores are 624.0 and 624
# Reverse doesn't match gene: scores are 395.0 and 540
# Reverse aligns to backbone: scores are 580.0 and 580
# 55
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1073_MMSYN1_0632_M13-Forward---20-_A10.ab1
# Validating MMSYN1_0632 (1-A10)
# Quality 60.1379928315 60.3447684391
# Forward doesn't match gene: scores are 305.0 and 509
# Forward aligns to backbone: scores are 558.0 and 558
# Reverse doesn't match gene: scores are 318.0 and 542
# Reverse aligns to backbone: scores are 583.0 and 583
# 56
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1074_MMSYN1_0772_M13-Forward---20-_B10.ab1
# Validating MMSYN1_0772 (1-B10)
# Quality 60.2798742138 59.5837651123
# Forward doesn't match gene: scores are 333.0 and 585
# Forward aligns to backbone: scores are 636.0 and 636
# Reverse doesn't match gene: scores are 314.0 and 539
# Reverse aligns to backbone: scores are 579.0 and 579
# 57
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1075_MMSYN1_0881_M13-Forward---20-_C10.ab1
# Validating MMSYN1_0881 (1-C10)
# Quality 59.9936 59.7567084079
# Forward doesn't match gene: scores are 528.0 and 576
# Forward aligns to backbone: scores are 625.0 and 625
# Reverse doesn't match gene: scores are 485.0 and 518
# Reverse aligns to backbone: scores are 559.0 and 559
# 58
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1076_MMSYN1_0401_M13-Forward---20-_D10.ab1
# Validating MMSYN1_0401 (1-D10)
# Quality 59.8413461538 60.0051724138
# Forward doesn't match gene: scores are 539.0 and 576
# Forward aligns to backbone: scores are 624.0 and 624
# Reverse doesn't match gene: scores are 520.0 and 540
# Reverse aligns to backbone: scores are 580.0 and 580
# 59
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1077_MMSYN1_0909_M13-Forward---20-_E10.ab1
# Validating MMSYN1_0909 (1-E10)
# Quality 60.3204508857 57.6821862348
# Forward doesn't match gene: scores are 269.0 and 574
# Forward aligns to backbone: scores are 621.0 and 621
# Reverse doesn't match gene: scores are 247.0 and 468
# Reverse aligns to backbone: scores are 494.0 and 494
# 60
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1078_MMSYN1_0154_M13-Forward---20-_F10.ab1
# Validating MMSYN1_0154 (1-F10)
# Quality 60.2362459547 60.6867256637
# Forward doesn't match gene: scores are 516.0 and 569
# Forward aligns to backbone: scores are 618.0 and 618
# Reverse doesn't match gene: scores are 482.0 and 518
# Reverse aligns to backbone: scores are 565.0 and 565
# 61
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1079_MMSYN1_0063_M13-Forward---20-_G10.ab1
# Validating MMSYN1_0063 (1-G10)
# Quality 60.1587301587 60.3808724832
# Forward matches gene: scores are 584.0 and 584
# Reverse matches gene: scores are 549.0 and 549
# 13
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1080_MMSYN1_0109_M13-Forward---20-_H10.ab1
# Validating MMSYN1_0109 (1-H10)
# Quality 59.9181380417 58.1234256927
# Forward doesn't match gene: scores are 443.0 and 571
# Forward aligns to backbone: scores are 623.0 and 623
# Reverse doesn't match gene: scores are 348.0 and 391
# Reverse aligns to backbone: scores are 397.0 and 397
# 62
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1081_MMSYN1_0314_M13-Forward---20-_A11.ab1
# Validating MMSYN1_0314 (1-A11)
# Quality 60.3784219002 60.3595317726
# Forward matches gene: scores are 571.0 and 571
# Reverse matches gene: scores are 554.0 and 554
# 14
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1082_MMSYN1_0197_M13-Forward---20-_B11.ab1
# Validating MMSYN1_0197 (1-B11)
# Quality 60.4806338028 60.5965811966
# Forward doesn't match gene: scores are 448.0 and 521
# Forward aligns to backbone: scores are 568.0 and 568
# Reverse doesn't match gene: scores are 462.0 and 541
# Reverse aligns to backbone: scores are 585.0 and 585
# 63
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1083_MMSYN1_0438_M13-Forward---20-_C11.ab1
# Validating MMSYN1_0438 (1-C11)
# Quality 60.395229983 59.4329738059
# Forward matches gene: scores are 399.0 and 537
# Reverse matches gene: scores are 399.0 and 603
# 15
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1084_MMSYN1_0332_M13-Forward---20-_D11.ab1
# Validating MMSYN1_0332 (1-D11)
# Quality 60.5233494364 59.6810344828
# Forward doesn't match gene: scores are 430.0 and 574
# Forward aligns to backbone: scores are 621.0 and 621
# Reverse doesn't match gene: scores are 405.0 and 540
# Reverse aligns to backbone: scores are 580.0 and 580
# 64
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1085_MMSYN1_0430_M13-Forward---20-_E11.ab1
# Validating MMSYN1_0430 (1-E11)
# Quality 60.0862619808 60.4733218589
# Forward doesn't match gene: scores are 267.0 and 576
# Forward aligns to backbone: scores are 626.0 and 626
# Reverse doesn't match gene: scores are 269.0 and 540
# Reverse aligns to backbone: scores are 581.0 and 581
# 65
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1086_MMSYN1_0353_M13-Forward---20-_F11.ab1
# Validating MMSYN1_0353 (1-F11)
# Quality 60.0446570973 59.9595070423
# Forward doesn't match gene: scores are 290.0 and 576
# Forward aligns to backbone: scores are 627.0 and 627
# Reverse doesn't match gene: scores are 284.0 and 528
# Reverse aligns to backbone: scores are 568.0 and 568
# 66
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1087_MMSYN1_0375_M13-Forward---20-_G11.ab1
# Validating MMSYN1_0375 (1-G11)
# Quality 60.4891696751 59.5385996409
# Forward doesn't match gene: scores are 380.0 and 505
# Forward aligns to backbone: scores are 554.0 and 554
# Reverse doesn't match gene: scores are 377.0 and 517
# Reverse aligns to backbone: scores are 557.0 and 557
# 67
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1088_MMSYN1_0730_M13-Forward---20-_H11.ab1
# Validating MMSYN1_0730 (1-H11)
# Quality 60.0257352941 60.1717902351
# Forward doesn't match gene: scores are 346.0 and 497
# Forward aligns to backbone: scores are 544.0 and 544
# Reverse doesn't match gene: scores are 355.0 and 513
# Reverse aligns to backbone: scores are 553.0 and 553
# 68
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1089_MMSYN1_0222_M13-Forward---20-_A12.ab1
# Validating MMSYN1_0222 (1-A12)
# Quality 60.6589403974 60.3474714519
# Forward doesn't match gene: scores are 546.0 and 553
# Forward aligns to backbone: scores are 604.0 and 604
# Reverse doesn't match gene: scores are 566.0 and 574
# Reverse aligns to backbone: scores are 613.0 and 613
# 69
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1090_MMSYN1_0526_link_MMSYN1_0499_M13-Forward---20-_B12.ab1
# Validating MMSYN1_0526_link_MMSYN1_0499 (1-B12)
# Quality 59.8971061093 60.361774744
# Forward doesn't match gene: scores are 174.0 and 572
# Forward aligns to backbone: scores are 622.0 and 622
# Reverse doesn't match gene: scores are 176.0 and 541
# Reverse aligns to backbone: scores are 586.0 and 586
# 70
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1091_MMSYN1_0852_link_MMSYN1_0778_M13-Forward---20-_C12.ab1
# Validating MMSYN1_0852_link_MMSYN1_0778 (1-C12)
# Quality 60.0701754386 60.6283783784
# Forward doesn't match gene: scores are 213.0 and 576
# Forward aligns to backbone: scores are 627.0 and 627
# Reverse doesn't match gene: scores are 205.0 and 552
# Reverse aligns to backbone: scores are 592.0 and 592
# 71
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1092_MMSYN1_0400_M13-Forward---20-_D12.ab1
# Validating MMSYN1_0400 (1-D12)
# Quality 60.1485623003 60.202970297
# Forward doesn't match gene: scores are 359.0 and 574
# Forward aligns to backbone: scores are 626.0 and 626
# Reverse doesn't match gene: scores are 355.0 and 566
# Reverse aligns to backbone: scores are 606.0 and 606
# 72
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1093_MMSYN1_0408_M13-Forward---20-_E12.ab1
# Validating MMSYN1_0408 (1-E12)
# Quality 60.1952 60.5211505922
# Forward doesn't match gene: scores are 394.0 and 574
# Forward aligns to backbone: scores are 625.0 and 625
# Reverse doesn't match gene: scores are 381.0 and 543
# Reverse aligns to backbone: scores are 591.0 and 591
# 73
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1094_MMSYN1_0094_M13-Forward---20-_F12.ab1
# Validating MMSYN1_0094 (1-F12)
# Quality 59.9255121043 59.4353146853
# Forward doesn't match gene: scores are 373.0 and 492
# Forward aligns to backbone: scores are 537.0 and 537
# Reverse doesn't match gene: scores are 392.0 and 539
# Reverse aligns to backbone: scores are 572.0 and 572
# 74
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1095_MMSYN1_0376_M13-Forward---20-_G12.ab1
# Validating MMSYN1_0376 (1-G12)
# Quality 60.6466302368 60.0745233969
# Forward doesn't match gene: scores are 244.0 and 499
# Forward aligns to backbone: scores are 549.0 and 549
# Reverse doesn't match gene: scores are 256.0 and 526
# Reverse aligns to backbone: scores are 577.0 and 577
# 75
#
# Analysing sequence ../synth1/builds/build-1/sequencing/CM_525055-1096_MMSYN1_0060_M13-Forward---20-_H12.ab1
# Validating MMSYN1_0060 (1-H12)
# Quality 60.1294498382 60.3264957265
# Forward doesn't match gene: scores are 432.0 and 571
# Forward aligns to backbone: scores are 618.0 and 618
# Reverse doesn't match gene: scores are 412.0 and 541
# Reverse aligns to backbone: scores are 585.0 and 585
# 76
#
# good 15
# rfp 76
# 157

# %%
good
# Out:
#            Gene Well
# 0   MMSYN1_0115  A01
# 1   MMSYN1_0693  D01
# 2   MMSYN1_0346  F02
# 3   MMSYN1_0043  F03
# 4   MMSYN1_0686  D04
# 5   MMSYN1_0066  C05
# 6   MMSYN1_0326  F05
# 7   MMSYN1_0077  C06
# 8   MMSYN1_0440  A07
# 9   MMSYN1_0906  C07
# 10  MMSYN1_0220  A08
# 11  MMSYN1_0164  G09
# 12  MMSYN1_0063  G10
# 13  MMSYN1_0314  A11
# 14  MMSYN1_0438  C11

# %%
# %%HTML
# <script src=//cdn.bio.sh/msa/1.0/msa.min.gz.js></script>

# %%
bad_alignments[0].format('clustal')

# %%
from IPython.display import HTML
    
base = HTML('''
<script src=//cdn.bio.sh/msa/1.0/msa.min.gz.js></script>

<div id="alignment"></div>

<script type="text/Javascript">
var input = `''' + bad_alignments[0].format('clustal') + '''`;
var seqs = msa.io.clustal.parse(input);

var opts = {
    el: document.getElementById("alignment"),
    vis: {
      conserv: false,
      overviewbox: false
    },
    // smaller menu for JSBin
    menu: "small",
    bootstrapMenu: false,
    seqs: seqs
};

var m = new msa.msa(opts);
m.render();
</script>''')we

from IPython import display
display.display(base)

for align in bad_alignments:
    code = HTML('''
        <script type="text/Javascript">
            m.seqs = msa.io.clustal.parse(`{}`);
            m.render();
        </script>
    '''.format(align.format('clustal')))
    display.clear_output(wait=True)
    display.display((base, code))
    break
