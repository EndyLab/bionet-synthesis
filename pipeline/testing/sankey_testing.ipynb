# %%
## Create Sankey Canvas

import plotly.plotly as py

data = dict(
    type='sankey',
    domain = dict(
      x =  [0,1],
      y =  [0,1]
    ),
    orientation = "h",
    valueformat = ".0f",
    valuesuffix = "TWh"   
  )

layout =  dict(
    title = "Energy forecast for 2050<br>Source: Department of Energy & Climate Change, Tom Counsell via <a href='https://bost.ocks.org/mike/sankey/'>Mike Bostock</a>",
    font = dict(
      size = 10
    )
)

# %%
## Add Nodes

import plotly.plotly as py
import glob
import json


for file in glob.glob("./sankey_test.json"):
        print("Opening sankey file: ", file)
        with open(file,"r") as json_file:
            data = json.load(json_file)

data_trace = dict(
    type='sankey',
    width = 1118,
    height = 772,
    domain = dict(
      x =  [0,1],
      y =  [0,1]
    ),
    orientation = "h",
    valueformat = ".0f",
    valuesuffix = "genes",
    node = dict(
      pad = 15,
      thickness = 15,
      line = dict(
        color = "black",
        width = 0.5
      ),
      label =  data['data'][0]['node']['label'],
      color =  data['data'][0]['node']['color']
    ),
    link = dict(
      source =  data['data'][0]['link']['source'],
      target =  data['data'][0]['link']['target'],
      value =  data['data'][0]['link']['value'],
      label =  data['data'][0]['link']['label']
  ))

layout =  dict(
    title = "Test Sankey",
    font = dict(
      size = 10
    )
)

fig = dict(data=[data_trace], layout=layout)
py.iplot(fig, validate=False)
# Out:
# Opening sankey file:  ./sankey_test.json
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~conarymeyer/20.embed" height="525px" width="100%"></iframe>

# %%
## Queries the database and presents the status

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import json
import os
import glob
import re

info = []
contributors = []

ordered = 0
abandoned = 0
build_ready = 0
attempted = 0
unknown = 0
vector = 0
complete = 0

total_subs = 5

for sub in range(total_subs):
    sub = sub + 1
    print("sub", sub)

    info = []
    contributors = []

    ordered = 0
    abandoned = 0
    build_ready = 0
    attempted = 0
    unknown = 0
    vector = 0
    complete = 0
    
    for file in glob.glob("../../data/*/*.json"):
        #print(file)
        with open(file,"r") as json_file:
            data = json.load(json_file)
        
        if data["info"]["order_number"] != sub:
            continue
        
        author = data["author"]["name"]
        contributors.append(author)
        if data["status"]["ordered"] == bool("true"):
            ordered = ordered + 1
        if data["status"]["abandoned"] == "TRUE":
            abandoned = abandoned + 1
        if data["status"]["build_ready"] == "TRUE":
            build_ready = build_ready + 1
        if data["status"]["build_complete"] != "":
            attempted = attempted + 1
        if data["status"]["build_complete"] == "Good_Sequence":
            complete = complete + 1
        elif data["status"]["build_complete"] == "Original_Vector_Sequence":
            vector = vector + 1
        elif data["status"]["build_complete"] == "Unknown_Sequence":
            unknown = unknown + 1
            
    contributors = pd.Series(contributors)
    unique_cont = len(contributors.unique())
    production = ordered - (build_ready + abandoned)
    failures = (vector + unknown)
    not_attempted = (build_ready - attempted)
    print("Contributers :", unique_cont)
    print("Ordered :", ordered)
    print("Abandoned :", abandoned)
    print("Received :", build_ready)
    print("In Production : ", production)
    print("Build Attempted :", attempted)
    print("Verified Success :", complete)
    print("Failures :", failures)
    print("Not Yet Attempted :", not_attempted)
    print()
# Out:
# sub 1
# Contributers : 1
# Ordered : 438
# Abandoned : 28
# Received : 410
# In Production :  0
# Build Attempted : 267
# Verified Success : 149
# Failures : 118
# Not Yet Attempted : 143
#
# sub 2
# Contributers : 2
# Ordered : 27
# Abandoned : 6
# Received : 21
# In Production :  0
# Build Attempted : 0
# Verified Success : 0
# Failures : 0
# Not Yet Attempted : 21
#
# sub 3
# Contributers : 5
# Ordered : 68
# Abandoned : 1
# Received : 66
# In Production :  1
# Build Attempted : 0
# Verified Success : 0
# Failures : 0
# Not Yet Attempted : 66
#
# sub 4
# Contributers : 2
# Ordered : 101
# Abandoned : 0
# Received : 0
# In Production :  101
# Build Attempted : 0
# Verified Success : 0
# Failures : 0
# Not Yet Attempted : 0
#
# sub 5
# Contributers : 1
# Ordered : 5
# Abandoned : 0
# Received : 0
# In Production :  5
# Build Attempted : 0
# Verified Success : 0
# Failures : 0
# Not Yet Attempted : 0

# %%
## Queries the database and presents the status

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import json
import os
import glob
import re

info = []
contributors = []

ordered = 0
abandoned = 0
build_ready = 0
attempted = 0
unknown = 0
vector = 0
complete = 0

sub1 = 0
sub2 = 0
sub3 = 0
sub4 = 0
sub5 = 0

for file in glob.glob("../../data/*/*.json"):
    print(file)
    with open(file,"r") as json_file:
        data = json.load(json_file)
    author = data["author"]["name"]
    contributors.append(author)

    if data["info"]["order_number"] == 1:
        sub1 = sub1 + 1
    elif data["info"]["order_number"] == 2:
        sub2 = sub2 + 1
    elif data["info"]["order_number"] == 3:
        sub3 = sub3 + 1
    elif data["info"]["order_number"] == 4:
        sub4 = sub4 + 1
    elif data["info"]["order_number"] == 5:
        sub5 = sub5 + 1

    if data["status"]["ordered"] == bool("true"):
        ordered = ordered + 1
    if data["status"]["abandoned"] == "TRUE":
        abandoned = abandoned + 1
    if data["status"]["build_ready"] == "TRUE":
        build_ready = build_ready + 1
    if data["status"]["build_complete"] != "":
        attempted = attempted + 1
    if data["status"]["build_complete"] == "Good_Sequence":
        complete = complete + 1
    elif data["status"]["build_complete"] == "Original_Vector_Sequence":
        vector = vector + 1
    elif data["status"]["build_complete"] == "Unknown_Sequence":
        unknown = unknown + 1

contributors = pd.Series(contributors)
unique_cont = len(contributors.unique())
production = ordered - (build_ready + abandoned)
failures = (vector + unknown)
not_attempted = (build_ready - attempted)

print("Contributers :", unique_cont)
print("Ordered :", ordered)

print("2017.42 :", sub1)
print("2017.44 :", sub2)
print("2017.46 :", sub3)
print("2017.48 :", sub4)
print("2017.50 :", sub5)

print("Abandoned :", abandoned)
print("Received :", build_ready)
print("In Production : ", production)
print("Build Attempted :", attempted)
print("Verified Success :", complete)
print("Failures :", failures)
print("Not Yet Attempted :", not_attempted)
print()

y = 400
z = 200

submission1 = "2017.42 [{}] Total Ordered #2b5aa5.7".format(sub1)
submission2 = "2017.44 [{}] Total Ordered #2b5aa5.7".format(sub2)
submission3 = "2017.46 [{}] Total Ordered #2b5aa5.7".format(sub3)
submission4 = "2017.48 [{}] Total Ordered #2b5aa5.7".format(sub4)
submission5 = "2017.50 [{}] Total Ordered #2b5aa5.7".format(sub5)
aband = "Total Ordered [{}] Abandoned #ef8c81".format(abandoned)
rec = "Total Ordered [{}] Received #418fba.9".format(build_ready)
prod = "Total Ordered [{}] In Production #f7c862".format(production)
att = "Received [{}] Build Attempted #6e9db7.7".format(attempted)
ver = "Build Attempted [{}] Verified Success #43bc68.7".format(complete)
fail = "Build Attempted [{}] Failures #a8252b.7".format(failures)
#pro = "Build Attempted [{}] In Process  #e8c620.4".format()
not_att = "Received [{}] Not Yet Attempted #e2bec0".format(not_attempted)

sankey = submission1+"\n"+submission2+"\n"+submission3+"\n"+submission4+"\n"+submission5+"\n"+aband+"\n"+rec+"\n"+prod+"\n"+att+"\n"+ver+"\n"+fail+"\n"+not_att
print(sankey)
# Out:
# ../../data/BBF10K_000001/BBF10K_000001.json
# ../../data/BBF10K_000002/BBF10K_000002.json
# ../../data/BBF10K_000003/BBF10K_000003.json
# ../../data/BBF10K_000004/BBF10K_000004.json
# ../../data/BBF10K_000005/BBF10K_000005.json
# ../../data/BBF10K_000006/BBF10K_000006.json
# ../../data/BBF10K_000007/BBF10K_000007.json
# ../../data/BBF10K_000008/BBF10K_000008.json
# ../../data/BBF10K_000009/BBF10K_000009.json
# ../../data/BBF10K_000010/BBF10K_000010.json
# ../../data/BBF10K_000011/BBF10K_000011.json
# ../../data/BBF10K_000012/BBF10K_000012.json
# ../../data/BBF10K_000013/BBF10K_000013.json
# ../../data/BBF10K_000014/BBF10K_000014.json
# ../../data/BBF10K_000015/BBF10K_000015.json
# ../../data/BBF10K_000016/BBF10K_000016.json
# ../../data/BBF10K_000017/BBF10K_000017.json
# ../../data/BBF10K_000018/BBF10K_000018.json
# ../../data/BBF10K_000019/BBF10K_000019.json
# ../../data/BBF10K_000020/BBF10K_000020.json
# ../../data/BBF10K_000021/BBF10K_000021.json
# ../../data/BBF10K_000022/BBF10K_000022.json
# ../../data/BBF10K_000023/BBF10K_000023.json
# ../../data/BBF10K_000024/BBF10K_000024.json
# ../../data/BBF10K_000025/BBF10K_000025.json
# ../../data/BBF10K_000026/BBF10K_000026.json
# ../../data/BBF10K_000027/BBF10K_000027.json
# ../../data/BBF10K_000028/BBF10K_000028.json
# ../../data/BBF10K_000029/BBF10K_000029.json
# ../../data/BBF10K_000030/BBF10K_000030.json
# ../../data/BBF10K_000031/BBF10K_000031.json
# ../../data/BBF10K_000032/BBF10K_000032.json
# ../../data/BBF10K_000033/BBF10K_000033.json
# ../../data/BBF10K_000034/BBF10K_000034.json
# ../../data/BBF10K_000035/BBF10K_000035.json
# ../../data/BBF10K_000036/BBF10K_000036.json
# ../../data/BBF10K_000037/BBF10K_000037.json
# ../../data/BBF10K_000038/BBF10K_000038.json
# ../../data/BBF10K_000039/BBF10K_000039.json
# ../../data/BBF10K_000040/BBF10K_000040.json
# ../../data/BBF10K_000041/BBF10K_000041.json
# ../../data/BBF10K_000042/BBF10K_000042.json
# ../../data/BBF10K_000043/BBF10K_000043.json
# ../../data/BBF10K_000044/BBF10K_000044.json
# ../../data/BBF10K_000045/BBF10K_000045.json
# ../../data/BBF10K_000046/BBF10K_000046.json
# ../../data/BBF10K_000047/BBF10K_000047.json
# ../../data/BBF10K_000048/BBF10K_000048.json
# ../../data/BBF10K_000049/BBF10K_000049.json
# ../../data/BBF10K_000050/BBF10K_000050.json
# ../../data/BBF10K_000051/BBF10K_000051.json
# ../../data/BBF10K_000052/BBF10K_000052.json
# ../../data/BBF10K_000053/BBF10K_000053.json
# ../../data/BBF10K_000054/BBF10K_000054.json
# ../../data/BBF10K_000055/BBF10K_000055.json
# ../../data/BBF10K_000056/BBF10K_000056.json
# ../../data/BBF10K_000057/BBF10K_000057.json
# ../../data/BBF10K_000058/BBF10K_000058.json
# ../../data/BBF10K_000059/BBF10K_000059.json
# ../../data/BBF10K_000060/BBF10K_000060.json
# ../../data/BBF10K_000061/BBF10K_000061.json
# ../../data/BBF10K_000062/BBF10K_000062.json
# ../../data/BBF10K_000063/BBF10K_000063.json
# ../../data/BBF10K_000064/BBF10K_000064.json
# ../../data/BBF10K_000065/BBF10K_000065.json
# ../../data/BBF10K_000066/BBF10K_000066.json
# ../../data/BBF10K_000067/BBF10K_000067.json
# ../../data/BBF10K_000068/BBF10K_000068.json
# ../../data/BBF10K_000069/BBF10K_000069.json
# ../../data/BBF10K_000070/BBF10K_000070.json
# ../../data/BBF10K_000071/BBF10K_000071.json
# ../../data/BBF10K_000072/BBF10K_000072.json
# ../../data/BBF10K_000073/BBF10K_000073.json
# ../../data/BBF10K_000074/BBF10K_000074.json
# ../../data/BBF10K_000075/BBF10K_000075.json
# ../../data/BBF10K_000076/BBF10K_000076.json
# ../../data/BBF10K_000077/BBF10K_000077.json
# ../../data/BBF10K_000078/BBF10K_000078.json
# ../../data/BBF10K_000079/BBF10K_000079.json
# ../../data/BBF10K_000080/BBF10K_000080.json
# ../../data/BBF10K_000081/BBF10K_000081.json
# ../../data/BBF10K_000082/BBF10K_000082.json
# ../../data/BBF10K_000083/BBF10K_000083.json
# ../../data/BBF10K_000084/BBF10K_000084.json
# ../../data/BBF10K_000085/BBF10K_000085.json
# ../../data/BBF10K_000086/BBF10K_000086.json
# ../../data/BBF10K_000087/BBF10K_000087.json
# ../../data/BBF10K_000088/BBF10K_000088.json
# ../../data/BBF10K_000089/BBF10K_000089.json
# ../../data/BBF10K_000090/BBF10K_000090.json
# ../../data/BBF10K_000091/BBF10K_000091.json
# ../../data/BBF10K_000092/BBF10K_000092.json
# ../../data/BBF10K_000093/BBF10K_000093.json
# ../../data/BBF10K_000094/BBF10K_000094.json
# ../../data/BBF10K_000095/BBF10K_000095.json
# ../../data/BBF10K_000096/BBF10K_000096.json
# ../../data/BBF10K_000097/BBF10K_000097.json
# ../../data/BBF10K_000098/BBF10K_000098.json
# ../../data/BBF10K_000099/BBF10K_000099.json
# ../../data/BBF10K_000100/BBF10K_000100.json
# ../../data/BBF10K_000101/BBF10K_000101.json
# ../../data/BBF10K_000102/BBF10K_000102.json
# ../../data/BBF10K_000103/BBF10K_000103.json
# ../../data/BBF10K_000104/BBF10K_000104.json
# ../../data/BBF10K_000105/BBF10K_000105.json
# ../../data/BBF10K_000106/BBF10K_000106.json
# ../../data/BBF10K_000107/BBF10K_000107.json
# ../../data/BBF10K_000108/BBF10K_000108.json
# ../../data/BBF10K_000109/BBF10K_000109.json
# ../../data/BBF10K_000110/BBF10K_000110.json
# ../../data/BBF10K_000111/BBF10K_000111.json
# ../../data/BBF10K_000112/BBF10K_000112.json
# ../../data/BBF10K_000113/BBF10K_000113.json
# ../../data/BBF10K_000114/BBF10K_000114.json
# ../../data/BBF10K_000115/BBF10K_000115.json
# ../../data/BBF10K_000116/BBF10K_000116.json
# ../../data/BBF10K_000117/BBF10K_000117.json
# ../../data/BBF10K_000118/BBF10K_000118.json
# ../../data/BBF10K_000119/BBF10K_000119.json
# ../../data/BBF10K_000120/BBF10K_000120.json
# ../../data/BBF10K_000121/BBF10K_000121.json
# ../../data/BBF10K_000122/BBF10K_000122.json
# ../../data/BBF10K_000123/BBF10K_000123.json
# ../../data/BBF10K_000124/BBF10K_000124.json
# ../../data/BBF10K_000125/BBF10K_000125.json
# ../../data/BBF10K_000126/BBF10K_000126.json
# ../../data/BBF10K_000127/BBF10K_000127.json
# ../../data/BBF10K_000128/BBF10K_000128.json
# ../../data/BBF10K_000129/BBF10K_000129.json
# ../../data/BBF10K_000130/BBF10K_000130.json
# ../../data/BBF10K_000131/BBF10K_000131.json
# ../../data/BBF10K_000132/BBF10K_000132.json
# ../../data/BBF10K_000133/BBF10K_000133.json
# ../../data/BBF10K_000134/BBF10K_000134.json
# ../../data/BBF10K_000135/BBF10K_000135.json
# ../../data/BBF10K_000136/BBF10K_000136.json
# ../../data/BBF10K_000137/BBF10K_000137.json
# ../../data/BBF10K_000138/BBF10K_000138.json
# ../../data/BBF10K_000139/BBF10K_000139.json
# ../../data/BBF10K_000140/BBF10K_000140.json
# ../../data/BBF10K_000141/BBF10K_000141.json
# ../../data/BBF10K_000142/BBF10K_000142.json
# ../../data/BBF10K_000143/BBF10K_000143.json
# ../../data/BBF10K_000144/BBF10K_000144.json
# ../../data/BBF10K_000145/BBF10K_000145.json
# ../../data/BBF10K_000146/BBF10K_000146.json
# ../../data/BBF10K_000147/BBF10K_000147.json
# ../../data/BBF10K_000148/BBF10K_000148.json
# ../../data/BBF10K_000149/BBF10K_000149.json
# ../../data/BBF10K_000150/BBF10K_000150.json
# ../../data/BBF10K_000151/BBF10K_000151.json
# ../../data/BBF10K_000152/BBF10K_000152.json
# ../../data/BBF10K_000153/BBF10K_000153.json
# ../../data/BBF10K_000154/BBF10K_000154.json
# ../../data/BBF10K_000155/BBF10K_000155.json
# ../../data/BBF10K_000156/BBF10K_000156.json
# ../../data/BBF10K_000157/BBF10K_000157.json
# ../../data/BBF10K_000158/BBF10K_000158.json
# ../../data/BBF10K_000159/BBF10K_000159.json
# ../../data/BBF10K_000160/BBF10K_000160.json
# ../../data/BBF10K_000161/BBF10K_000161.json
# ../../data/BBF10K_000162/BBF10K_000162.json
# ../../data/BBF10K_000163/BBF10K_000163.json
# ../../data/BBF10K_000164/BBF10K_000164.json
# ../../data/BBF10K_000165/BBF10K_000165.json
# ../../data/BBF10K_000166/BBF10K_000166.json
# ../../data/BBF10K_000167/BBF10K_000167.json
# ../../data/BBF10K_000168/BBF10K_000168.json
# ../../data/BBF10K_000169/BBF10K_000169.json
# ../../data/BBF10K_000170/BBF10K_000170.json
# ../../data/BBF10K_000171/BBF10K_000171.json
# ../../data/BBF10K_000172/BBF10K_000172.json
# ../../data/BBF10K_000173/BBF10K_000173.json
# ../../data/BBF10K_000174/BBF10K_000174.json
# ../../data/BBF10K_000175/BBF10K_000175.json
# ../../data/BBF10K_000176/BBF10K_000176.json
# ../../data/BBF10K_000177/BBF10K_000177.json
# ../../data/BBF10K_000178/BBF10K_000178.json
# ../../data/BBF10K_000179/BBF10K_000179.json
# ../../data/BBF10K_000180/BBF10K_000180.json
# ../../data/BBF10K_000181/BBF10K_000181.json
# ../../data/BBF10K_000182/BBF10K_000182.json
# ../../data/BBF10K_000183/BBF10K_000183.json
# ../../data/BBF10K_000184/BBF10K_000184.json
# ../../data/BBF10K_000185/BBF10K_000185.json
# ../../data/BBF10K_000186/BBF10K_000186.json
# ../../data/BBF10K_000187/BBF10K_000187.json
# ../../data/BBF10K_000188/BBF10K_000188.json
# ../../data/BBF10K_000189/BBF10K_000189.json
# ../../data/BBF10K_000190/BBF10K_000190.json
# ../../data/BBF10K_000191/BBF10K_000191.json
# ../../data/BBF10K_000192/BBF10K_000192.json
# ../../data/BBF10K_000193/BBF10K_000193.json
# ../../data/BBF10K_000194/BBF10K_000194.json
# ../../data/BBF10K_000195/BBF10K_000195.json
# ../../data/BBF10K_000196/BBF10K_000196.json
# ../../data/BBF10K_000197/BBF10K_000197.json
# ../../data/BBF10K_000198/BBF10K_000198.json
# ../../data/BBF10K_000199/BBF10K_000199.json
# ../../data/BBF10K_000200/BBF10K_000200.json
# ../../data/BBF10K_000201/BBF10K_000201.json
# ../../data/BBF10K_000202/BBF10K_000202.json
# ../../data/BBF10K_000203/BBF10K_000203.json
# ../../data/BBF10K_000204/BBF10K_000204.json
# ../../data/BBF10K_000205/BBF10K_000205.json
# ../../data/BBF10K_000206/BBF10K_000206.json
# ../../data/BBF10K_000207/BBF10K_000207.json
# ../../data/BBF10K_000208/BBF10K_000208.json
# ../../data/BBF10K_000209/BBF10K_000209.json
# ../../data/BBF10K_000210/BBF10K_000210.json
# ../../data/BBF10K_000211/BBF10K_000211.json
# ../../data/BBF10K_000212/BBF10K_000212.json
# ../../data/BBF10K_000213/BBF10K_000213.json
# ../../data/BBF10K_000214/BBF10K_000214.json
# ../../data/BBF10K_000215/BBF10K_000215.json
# ../../data/BBF10K_000216/BBF10K_000216.json
# ../../data/BBF10K_000217/BBF10K_000217.json
# ../../data/BBF10K_000218/BBF10K_000218.json
# ../../data/BBF10K_000219/BBF10K_000219.json
# ../../data/BBF10K_000220/BBF10K_000220.json
# ../../data/BBF10K_000221/BBF10K_000221.json
# ../../data/BBF10K_000222/BBF10K_000222.json
# ../../data/BBF10K_000223/BBF10K_000223.json
# ../../data/BBF10K_000224/BBF10K_000224.json
# ../../data/BBF10K_000225/BBF10K_000225.json
# ../../data/BBF10K_000226/BBF10K_000226.json
# ../../data/BBF10K_000227/BBF10K_000227.json
# ../../data/BBF10K_000228/BBF10K_000228.json
# ../../data/BBF10K_000229/BBF10K_000229.json
# ../../data/BBF10K_000230/BBF10K_000230.json
# ../../data/BBF10K_000231/BBF10K_000231.json
# ../../data/BBF10K_000232/BBF10K_000232.json
# ../../data/BBF10K_000233/BBF10K_000233.json
# ../../data/BBF10K_000234/BBF10K_000234.json
# ../../data/BBF10K_000235/BBF10K_000235.json
# ../../data/BBF10K_000236/BBF10K_000236.json
# ../../data/BBF10K_000237/BBF10K_000237.json
# ../../data/BBF10K_000238/BBF10K_000238.json
# ../../data/BBF10K_000239/BBF10K_000239.json
# ../../data/BBF10K_000240/BBF10K_000240.json
# ../../data/BBF10K_000241/BBF10K_000241.json
# ../../data/BBF10K_000242/BBF10K_000242.json
# ../../data/BBF10K_000243/BBF10K_000243.json
# ../../data/BBF10K_000244/BBF10K_000244.json
# ../../data/BBF10K_000245/BBF10K_000245.json
# ../../data/BBF10K_000246/BBF10K_000246.json
# ../../data/BBF10K_000247/BBF10K_000247.json
# ../../data/BBF10K_000248/BBF10K_000248.json
# ../../data/BBF10K_000249/BBF10K_000249.json
# ../../data/BBF10K_000250/BBF10K_000250.json
# ../../data/BBF10K_000251/BBF10K_000251.json
# ../../data/BBF10K_000252/BBF10K_000252.json
# ../../data/BBF10K_000253/BBF10K_000253.json
# ../../data/BBF10K_000254/BBF10K_000254.json
# ../../data/BBF10K_000255/BBF10K_000255.json
# ../../data/BBF10K_000256/BBF10K_000256.json
# ../../data/BBF10K_000257/BBF10K_000257.json
# ../../data/BBF10K_000258/BBF10K_000258.json
# ../../data/BBF10K_000259/BBF10K_000259.json
# ../../data/BBF10K_000260/BBF10K_000260.json
# ../../data/BBF10K_000261/BBF10K_000261.json
# ../../data/BBF10K_000262/BBF10K_000262.json
# ../../data/BBF10K_000263/BBF10K_000263.json
# ../../data/BBF10K_000264/BBF10K_000264.json
# ../../data/BBF10K_000265/BBF10K_000265.json
# ../../data/BBF10K_000266/BBF10K_000266.json
# ../../data/BBF10K_000267/BBF10K_000267.json
# ../../data/BBF10K_000268/BBF10K_000268.json
# ../../data/BBF10K_000269/BBF10K_000269.json
# ../../data/BBF10K_000270/BBF10K_000270.json
# ../../data/BBF10K_000271/BBF10K_000271.json
# ../../data/BBF10K_000272/BBF10K_000272.json
# ../../data/BBF10K_000273/BBF10K_000273.json
# ../../data/BBF10K_000274/BBF10K_000274.json
# ../../data/BBF10K_000275/BBF10K_000275.json
# ../../data/BBF10K_000276/BBF10K_000276.json
# ../../data/BBF10K_000277/BBF10K_000277.json
# ../../data/BBF10K_000278/BBF10K_000278.json
# ../../data/BBF10K_000279/BBF10K_000279.json
# ../../data/BBF10K_000280/BBF10K_000280.json
# ../../data/BBF10K_000281/BBF10K_000281.json
# ../../data/BBF10K_000282/BBF10K_000282.json
# ../../data/BBF10K_000283/BBF10K_000283.json
# ../../data/BBF10K_000284/BBF10K_000284.json
# ../../data/BBF10K_000285/BBF10K_000285.json
# ../../data/BBF10K_000286/BBF10K_000286.json
# ../../data/BBF10K_000287/BBF10K_000287.json
# ../../data/BBF10K_000288/BBF10K_000288.json
# ../../data/BBF10K_000289/BBF10K_000289.json
# ../../data/BBF10K_000290/BBF10K_000290.json
# ../../data/BBF10K_000291/BBF10K_000291.json
# ../../data/BBF10K_000292/BBF10K_000292.json
# ../../data/BBF10K_000293/BBF10K_000293.json
# ../../data/BBF10K_000294/BBF10K_000294.json
# ../../data/BBF10K_000295/BBF10K_000295.json
# ../../data/BBF10K_000296/BBF10K_000296.json
# ../../data/BBF10K_000297/BBF10K_000297.json
# ../../data/BBF10K_000298/BBF10K_000298.json
# ../../data/BBF10K_000299/BBF10K_000299.json
# ../../data/BBF10K_000300/BBF10K_000300.json
# ../../data/BBF10K_000301/BBF10K_000301.json
# ../../data/BBF10K_000302/BBF10K_000302.json
# ../../data/BBF10K_000303/BBF10K_000303.json
# ../../data/BBF10K_000304/BBF10K_000304.json
# ../../data/BBF10K_000305/BBF10K_000305.json
# ../../data/BBF10K_000306/BBF10K_000306.json
# ../../data/BBF10K_000307/BBF10K_000307.json
# ../../data/BBF10K_000308/BBF10K_000308.json
# ../../data/BBF10K_000309/BBF10K_000309.json
# ../../data/BBF10K_000310/BBF10K_000310.json
# ../../data/BBF10K_000311/BBF10K_000311.json
# ../../data/BBF10K_000312/BBF10K_000312.json
# ../../data/BBF10K_000313/BBF10K_000313.json
# ../../data/BBF10K_000314/BBF10K_000314.json
# ../../data/BBF10K_000315/BBF10K_000315.json
# ../../data/BBF10K_000316/BBF10K_000316.json
# ../../data/BBF10K_000317/BBF10K_000317.json
# ../../data/BBF10K_000318/BBF10K_000318.json
# ../../data/BBF10K_000319/BBF10K_000319.json
# ../../data/BBF10K_000320/BBF10K_000320.json
# ../../data/BBF10K_000321/BBF10K_000321.json
# ../../data/BBF10K_000322/BBF10K_000322.json
# ../../data/BBF10K_000323/BBF10K_000323.json
# ../../data/BBF10K_000324/BBF10K_000324.json
# ../../data/BBF10K_000325/BBF10K_000325.json
# ../../data/BBF10K_000326/BBF10K_000326.json
# ../../data/BBF10K_000327/BBF10K_000327.json
# ../../data/BBF10K_000328/BBF10K_000328.json
# ../../data/BBF10K_000329/BBF10K_000329.json
# ../../data/BBF10K_000330/BBF10K_000330.json
# ../../data/BBF10K_000331/BBF10K_000331.json
# ../../data/BBF10K_000332/BBF10K_000332.json
# ../../data/BBF10K_000333/BBF10K_000333.json
# ../../data/BBF10K_000334/BBF10K_000334.json
# ../../data/BBF10K_000335/BBF10K_000335.json
# ../../data/BBF10K_000336/BBF10K_000336.json
# ../../data/BBF10K_000337/BBF10K_000337.json
# ../../data/BBF10K_000338/BBF10K_000338.json
# ../../data/BBF10K_000339/BBF10K_000339.json
# ../../data/BBF10K_000340/BBF10K_000340.json
# ../../data/BBF10K_000341/BBF10K_000341.json
# ../../data/BBF10K_000342/BBF10K_000342.json
# ../../data/BBF10K_000343/BBF10K_000343.json
# ../../data/BBF10K_000344/BBF10K_000344.json
# ../../data/BBF10K_000345/BBF10K_000345.json
# ../../data/BBF10K_000346/BBF10K_000346.json
# ../../data/BBF10K_000347/BBF10K_000347.json
# ../../data/BBF10K_000348/BBF10K_000348.json
# ../../data/BBF10K_000349/BBF10K_000349.json
# ../../data/BBF10K_000350/BBF10K_000350.json
# ../../data/BBF10K_000351/BBF10K_000351.json
# ../../data/BBF10K_000352/BBF10K_000352.json
# ../../data/BBF10K_000353/BBF10K_000353.json
# ../../data/BBF10K_000354/BBF10K_000354.json
# ../../data/BBF10K_000355/BBF10K_000355.json
# ../../data/BBF10K_000356/BBF10K_000356.json
# ../../data/BBF10K_000357/BBF10K_000357.json
# ../../data/BBF10K_000358/BBF10K_000358.json
# ../../data/BBF10K_000359/BBF10K_000359.json
# ../../data/BBF10K_000360/BBF10K_000360.json
# ../../data/BBF10K_000361/BBF10K_000361.json
# ../../data/BBF10K_000362/BBF10K_000362.json
# ../../data/BBF10K_000363/BBF10K_000363.json
# ../../data/BBF10K_000364/BBF10K_000364.json
# ../../data/BBF10K_000365/BBF10K_000365.json
# ../../data/BBF10K_000366/BBF10K_000366.json
# ../../data/BBF10K_000367/BBF10K_000367.json
# ../../data/BBF10K_000368/BBF10K_000368.json
# ../../data/BBF10K_000369/BBF10K_000369.json
# ../../data/BBF10K_000370/BBF10K_000370.json
# ../../data/BBF10K_000371/BBF10K_000371.json
# ../../data/BBF10K_000372/BBF10K_000372.json
# ../../data/BBF10K_000373/BBF10K_000373.json
# ../../data/BBF10K_000374/BBF10K_000374.json
# ../../data/BBF10K_000375/BBF10K_000375.json
# ../../data/BBF10K_000376/BBF10K_000376.json
# ../../data/BBF10K_000377/BBF10K_000377.json
# ../../data/BBF10K_000378/BBF10K_000378.json
# ../../data/BBF10K_000379/BBF10K_000379.json
# ../../data/BBF10K_000380/BBF10K_000380.json
# ../../data/BBF10K_000381/BBF10K_000381.json
# ../../data/BBF10K_000382/BBF10K_000382.json
# ../../data/BBF10K_000383/BBF10K_000383.json
# ../../data/BBF10K_000384/BBF10K_000384.json
# ../../data/BBF10K_000385/BBF10K_000385.json
# ../../data/BBF10K_000386/BBF10K_000386.json
# ../../data/BBF10K_000387/BBF10K_000387.json
# ../../data/BBF10K_000388/BBF10K_000388.json
# ../../data/BBF10K_000389/BBF10K_000389.json
# ../../data/BBF10K_000390/BBF10K_000390.json
# ../../data/BBF10K_000391/BBF10K_000391.json
# ../../data/BBF10K_000392/BBF10K_000392.json
# ../../data/BBF10K_000393/BBF10K_000393.json
# ../../data/BBF10K_000394/BBF10K_000394.json
# ../../data/BBF10K_000395/BBF10K_000395.json
# ../../data/BBF10K_000396/BBF10K_000396.json
# ../../data/BBF10K_000397/BBF10K_000397.json
# ../../data/BBF10K_000398/BBF10K_000398.json
# ../../data/BBF10K_000399/BBF10K_000399.json
# ../../data/BBF10K_000400/BBF10K_000400.json
# ../../data/BBF10K_000401/BBF10K_000401.json
# ../../data/BBF10K_000402/BBF10K_000402.json
# ../../data/BBF10K_000403/BBF10K_000403.json
# ../../data/BBF10K_000404/BBF10K_000404.json
# ../../data/BBF10K_000405/BBF10K_000405.json
# ../../data/BBF10K_000406/BBF10K_000406.json
# ../../data/BBF10K_000407/BBF10K_000407.json
# ../../data/BBF10K_000408/BBF10K_000408.json
# ../../data/BBF10K_000409/BBF10K_000409.json
# ../../data/BBF10K_000410/BBF10K_000410.json
# ../../data/BBF10K_000411/BBF10K_000411.json
# ../../data/BBF10K_000412/BBF10K_000412.json
# ../../data/BBF10K_000413/BBF10K_000413.json
# ../../data/BBF10K_000414/BBF10K_000414.json
# ../../data/BBF10K_000415/BBF10K_000415.json
# ../../data/BBF10K_000416/BBF10K_000416.json
# ../../data/BBF10K_000417/BBF10K_000417.json
# ../../data/BBF10K_000418/BBF10K_000418.json
# ../../data/BBF10K_000419/BBF10K_000419.json
# ../../data/BBF10K_000420/BBF10K_000420.json
# ../../data/BBF10K_000421/BBF10K_000421.json
# ../../data/BBF10K_000422/BBF10K_000422.json
# ../../data/BBF10K_000423/BBF10K_000423.json
# ../../data/BBF10K_000424/BBF10K_000424.json
# ../../data/BBF10K_000425/BBF10K_000425.json
# ../../data/BBF10K_000426/BBF10K_000426.json
# ../../data/BBF10K_000427/BBF10K_000427.json
# ../../data/BBF10K_000428/BBF10K_000428.json
# ../../data/BBF10K_000429/BBF10K_000429.json
# ../../data/BBF10K_000430/BBF10K_000430.json
# ../../data/BBF10K_000431/BBF10K_000431.json
# ../../data/BBF10K_000432/BBF10K_000432.json
# ../../data/BBF10K_000433/BBF10K_000433.json
# ../../data/BBF10K_000434/BBF10K_000434.json
# ../../data/BBF10K_000435/BBF10K_000435.json
# ../../data/BBF10K_000436/BBF10K_000436.json
# ../../data/BBF10K_000437/BBF10K_000437.json
# ../../data/BBF10K_000438/BBF10K_000438.json
# ../../data/BBF10K_000439/BBF10K_000439.json
# ../../data/BBF10K_000440/BBF10K_000440.json
# ../../data/BBF10K_000441/BBF10K_000441.json
# ../../data/BBF10K_000442/BBF10K_000442.json
# ../../data/BBF10K_000443/BBF10K_000443.json
# ../../data/BBF10K_000444/BBF10K_000444.json
# ../../data/BBF10K_000445/BBF10K_000445.json
# ../../data/BBF10K_000446/BBF10K_000446.json
# ../../data/BBF10K_000447/BBF10K_000447.json
# ../../data/BBF10K_000448/BBF10K_000448.json
# ../../data/BBF10K_000449/BBF10K_000449.json
# ../../data/BBF10K_000450/BBF10K_000450.json
# ../../data/BBF10K_000451/BBF10K_000451.json
# ../../data/BBF10K_000452/BBF10K_000452.json
# ../../data/BBF10K_000453/BBF10K_000453.json
# ../../data/BBF10K_000454/BBF10K_000454.json
# ../../data/BBF10K_000455/BBF10K_000455.json
# ../../data/BBF10K_000456/BBF10K_000456.json
# ../../data/BBF10K_000457/BBF10K_000457.json
# ../../data/BBF10K_000458/BBF10K_000458.json
# ../../data/BBF10K_000459/BBF10K_000459.json
# ../../data/BBF10K_000460/BBF10K_000460.json
# ../../data/BBF10K_000461/BBF10K_000461.json
# ../../data/BBF10K_000462/BBF10K_000462.json
# ../../data/BBF10K_000463/BBF10K_000463.json
# ../../data/BBF10K_000464/BBF10K_000464.json
# ../../data/BBF10K_000465/BBF10K_000465.json
# ../../data/BBF10K_000466/BBF10K_000466.json
# ../../data/BBF10K_000467/BBF10K_000467.json
# ../../data/BBF10K_000468/BBF10K_000468.json
# ../../data/BBF10K_000469/BBF10K_000469.json
# ../../data/BBF10K_000470/BBF10K_000470.json
# ../../data/BBF10K_000471/BBF10K_000471.json
# ../../data/BBF10K_000472/BBF10K_000472.json
# ../../data/BBF10K_000473/BBF10K_000473.json
# ../../data/BBF10K_000474/BBF10K_000474.json
# ../../data/BBF10K_000475/BBF10K_000475.json
# ../../data/BBF10K_000476/BBF10K_000476.json
# ../../data/BBF10K_000477/BBF10K_000477.json
# ../../data/BBF10K_000478/BBF10K_000478.json
# ../../data/BBF10K_000479/BBF10K_000479.json
# ../../data/BBF10K_000480/BBF10K_000480.json
# ../../data/BBF10K_000481/BBF10K_000481.json
# ../../data/BBF10K_000482/BBF10K_000482.json
# ../../data/BBF10K_000483/BBF10K_000483.json
# ../../data/BBF10K_000484/BBF10K_000484.json
# ../../data/BBF10K_000485/BBF10K_000485.json
# ../../data/BBF10K_000486/BBF10K_000486.json
# ../../data/BBF10K_000487/BBF10K_000487.json
# ../../data/BBF10K_000488/BBF10K_000488.json
# ../../data/BBF10K_000489/BBF10K_000489.json
# ../../data/BBF10K_000490/BBF10K_000490.json
# ../../data/BBF10K_000491/BBF10K_000491.json
# ../../data/BBF10K_000492/BBF10K_000492.json
# ../../data/BBF10K_000493/BBF10K_000493.json
# ../../data/BBF10K_000494/BBF10K_000494.json
# ../../data/BBF10K_000495/BBF10K_000495.json
# ../../data/BBF10K_000496/BBF10K_000496.json
# ../../data/BBF10K_000497/BBF10K_000497.json
# ../../data/BBF10K_000498/BBF10K_000498.json
# ../../data/BBF10K_000499/BBF10K_000499.json
# ../../data/BBF10K_000500/BBF10K_000500.json
# ../../data/BBF10K_000501/BBF10K_000501.json
# ../../data/BBF10K_000502/BBF10K_000502.json
# ../../data/BBF10K_000503/BBF10K_000503.json
# ../../data/BBF10K_000504/BBF10K_000504.json
# ../../data/BBF10K_000505/BBF10K_000505.json
# ../../data/BBF10K_000506/BBF10K_000506.json
# ../../data/BBF10K_000507/BBF10K_000507.json
# ../../data/BBF10K_000508/BBF10K_000508.json
# ../../data/BBF10K_000509/BBF10K_000509.json
# ../../data/BBF10K_000510/BBF10K_000510.json
# ../../data/BBF10K_000511/BBF10K_000511.json
# ../../data/BBF10K_000512/BBF10K_000512.json
# ../../data/BBF10K_000513/BBF10K_000513.json
# ../../data/BBF10K_000514/BBF10K_000514.json
# ../../data/BBF10K_000515/BBF10K_000515.json
# ../../data/BBF10K_000516/BBF10K_000516.json
# ../../data/BBF10K_000517/BBF10K_000517.json
# ../../data/BBF10K_000518/BBF10K_000518.json
# ../../data/BBF10K_000519/BBF10K_000519.json
# ../../data/BBF10K_000520/BBF10K_000520.json
# ../../data/BBF10K_000521/BBF10K_000521.json
# ../../data/BBF10K_000522/BBF10K_000522.json
# ../../data/BBF10K_000523/BBF10K_000523.json
# ../../data/BBF10K_000524/BBF10K_000524.json
# ../../data/BBF10K_000525/BBF10K_000525.json
# ../../data/BBF10K_000526/BBF10K_000526.json
# ../../data/BBF10K_000527/BBF10K_000527.json
# ../../data/BBF10K_000528/BBF10K_000528.json
# ../../data/BBF10K_000529/BBF10K_000529.json
# ../../data/BBF10K_000530/BBF10K_000530.json
# ../../data/BBF10K_000531/BBF10K_000531.json
# ../../data/BBF10K_000532/BBF10K_000532.json
# ../../data/BBF10K_000533/BBF10K_000533.json
# ../../data/BBF10K_000534/BBF10K_000534.json
# ../../data/BBF10K_000535/BBF10K_000535.json
# ../../data/BBF10K_000536/BBF10K_000536.json
# ../../data/BBF10K_000537/BBF10K_000537.json
# ../../data/BBF10K_000538/BBF10K_000538.json
# ../../data/BBF10K_000539/BBF10K_000539.json
# ../../data/BBF10K_000540/BBF10K_000540.json
# ../../data/BBF10K_000541/BBF10K_000541.json
# ../../data/BBF10K_000542/BBF10K_000542.json
# ../../data/BBF10K_000543/BBF10K_000543.json
# ../../data/BBF10K_000544/BBF10K_000544.json
# ../../data/BBF10K_000545/BBF10K_000545.json
# ../../data/BBF10K_000546/BBF10K_000546.json
# ../../data/BBF10K_000547/BBF10K_000547.json
# ../../data/BBF10K_000548/BBF10K_000548.json
# ../../data/BBF10K_000549/BBF10K_000549.json
# ../../data/BBF10K_000550/BBF10K_000550.json
# ../../data/BBF10K_000551/BBF10K_000551.json
# ../../data/BBF10K_000552/BBF10K_000552.json
# ../../data/BBF10K_000553/BBF10K_000553.json
# ../../data/BBF10K_000554/BBF10K_000554.json
# ../../data/BBF10K_000555/BBF10K_000555.json
# ../../data/BBF10K_000556/BBF10K_000556.json
# ../../data/BBF10K_000557/BBF10K_000557.json
# ../../data/BBF10K_000558/BBF10K_000558.json
# ../../data/BBF10K_000559/BBF10K_000559.json
# ../../data/BBF10K_000560/BBF10K_000560.json
# ../../data/BBF10K_000561/BBF10K_000561.json
# ../../data/BBF10K_000562/BBF10K_000562.json
# ../../data/BBF10K_000563/BBF10K_000563.json
# ../../data/BBF10K_000564/BBF10K_000564.json
# ../../data/BBF10K_000565/BBF10K_000565.json
# ../../data/BBF10K_000566/BBF10K_000566.json
# ../../data/BBF10K_000567/BBF10K_000567.json
# ../../data/BBF10K_000568/BBF10K_000568.json
# ../../data/BBF10K_000569/BBF10K_000569.json
# ../../data/BBF10K_000570/BBF10K_000570.json
# ../../data/BBF10K_000571/BBF10K_000571.json
# ../../data/BBF10K_000572/BBF10K_000572.json
# ../../data/BBF10K_000573/BBF10K_000573.json
# ../../data/BBF10K_000574/BBF10K_000574.json
# ../../data/BBF10K_000575/BBF10K_000575.json
# ../../data/BBF10K_000576/BBF10K_000576.json
# ../../data/BBF10K_000577/BBF10K_000577.json
# ../../data/BBF10K_000578/BBF10K_000578.json
# ../../data/BBF10K_000579/BBF10K_000579.json
# ../../data/BBF10K_000580/BBF10K_000580.json
# ../../data/BBF10K_000581/BBF10K_000581.json
# ../../data/BBF10K_000582/BBF10K_000582.json
# ../../data/BBF10K_000583/BBF10K_000583.json
# ../../data/BBF10K_000584/BBF10K_000584.json
# ../../data/BBF10K_000585/BBF10K_000585.json
# ../../data/BBF10K_000586/BBF10K_000586.json
# ../../data/BBF10K_000587/BBF10K_000587.json
# ../../data/BBF10K_000588/BBF10K_000588.json
# ../../data/BBF10K_000589/BBF10K_000589.json
# ../../data/BBF10K_000590/BBF10K_000590.json
# ../../data/BBF10K_000591/BBF10K_000591.json
# ../../data/BBF10K_000592/BBF10K_000592.json
# ../../data/BBF10K_000593/BBF10K_000593.json
# ../../data/BBF10K_000594/BBF10K_000594.json
# ../../data/BBF10K_000595/BBF10K_000595.json
# ../../data/BBF10K_000596/BBF10K_000596.json
# ../../data/BBF10K_000597/BBF10K_000597.json
# ../../data/BBF10K_000598/BBF10K_000598.json
# ../../data/BBF10K_000599/BBF10K_000599.json
# ../../data/BBF10K_000600/BBF10K_000600.json
# ../../data/BBF10K_000601/BBF10K_000601.json
# ../../data/BBF10K_000602/BBF10K_000602.json
# ../../data/BBF10K_000603/BBF10K_000603.json
# ../../data/BBF10K_000604/BBF10K_000604.json
# ../../data/BBF10K_000605/BBF10K_000605.json
# ../../data/BBF10K_000606/BBF10K_000606.json
# ../../data/BBF10K_000607/BBF10K_000607.json
# ../../data/BBF10K_000608/BBF10K_000608.json
# ../../data/BBF10K_000609/BBF10K_000609.json
# ../../data/BBF10K_000610/BBF10K_000610.json
# ../../data/BBF10K_000611/BBF10K_000611.json
# ../../data/BBF10K_000612/BBF10K_000612.json
# ../../data/BBF10K_000613/BBF10K_000613.json
# ../../data/BBF10K_000614/BBF10K_000614.json
# ../../data/BBF10K_000615/BBF10K_000615.json
# ../../data/BBF10K_000616/BBF10K_000616.json
# ../../data/BBF10K_000617/BBF10K_000617.json
# ../../data/BBF10K_000618/BBF10K_000618.json
# ../../data/BBF10K_000619/BBF10K_000619.json
# ../../data/BBF10K_000620/BBF10K_000620.json
# ../../data/BBF10K_000621/BBF10K_000621.json
# ../../data/BBF10K_000622/BBF10K_000622.json
# ../../data/BBF10K_000623/BBF10K_000623.json
# ../../data/BBF10K_000624/BBF10K_000624.json
# ../../data/BBF10K_000625/BBF10K_000625.json
# ../../data/BBF10K_000626/BBF10K_000626.json
# ../../data/BBF10K_000627/BBF10K_000627.json
# ../../data/BBF10K_000628/BBF10K_000628.json
# ../../data/BBF10K_000629/BBF10K_000629.json
# ../../data/BBF10K_000630/BBF10K_000630.json
# ../../data/BBF10K_000631/BBF10K_000631.json
# ../../data/BBF10K_000632/BBF10K_000632.json
# ../../data/BBF10K_000633/BBF10K_000633.json
# ../../data/BBF10K_000634/BBF10K_000634.json
# ../../data/BBF10K_000635/BBF10K_000635.json
# ../../data/BBF10K_000636/BBF10K_000636.json
# ../../data/BBF10K_000637/BBF10K_000637.json
# ../../data/BBF10K_000638/BBF10K_000638.json
# ../../data/BBF10K_000639/BBF10K_000639.json
# Contributers : 9
# Ordered : 639
# 2017.42 : 438
# 2017.44 : 27
# 2017.46 : 68
# 2017.48 : 101
# 2017.50 : 5
# Abandoned : 35
# Received : 497
# In Production :  107
# Build Attempted : 267
# Verified Success : 149
# Failures : 118
# Not Yet Attempted : 230
#
# 2017.42 [438] Total Ordered #2b5aa5.7
# 2017.44 [27] Total Ordered #2b5aa5.7
# 2017.46 [68] Total Ordered #2b5aa5.7
# 2017.48 [101] Total Ordered #2b5aa5.7
# 2017.50 [5] Total Ordered #2b5aa5.7
# Total Ordered [35] Abandoned #ef8c81
# Total Ordered [497] Received #418fba.9
# Total Ordered [107] In Production #f7c862
# Received [267] Build Attempted #6e9db7.7
# Build Attempted [149] Verified Success #43bc68.7
# Build Attempted [118] Failures #a8252b.7
# Received [230] Not Yet Attempted #e2bec0

# %%
## Add Links

import plotly.plotly as py

#plotly.tools.set_credentials_file(username='conarymeyer', api_key='sM5kLMqPTTg7LXFzubZ4')

#import plotly.graph_objs as go
#go.Sankey
import glob
import json
for file in glob.glob("./simple_sankey.json"):
        print("Opening sankey file: ", file)
        with open(file,"r") as json_file:
            data = json.load(json_file)

#node_labels = ["new label 1", "new label 2","new label 3","new label 4"]
#node_colors = ["rgba(31, 119, 180, 0.8)", "rgba(255, 127, 14, 0.8)","rgba(31, 119, 180, 0.8)","rgba(255, 127, 14, 0.8)"]
#
#
#counter = 0
#for label in node_labels:
#    data['data'][0]['node']['label'][counter] = label
#    counter = counter + 1
#    
#counter = 0
#for color in node_colors:
#    data['data'][0]['node']['color'][counter] = label
#    counter = counter + 1    
#
#counter = 0
#for color in node_colors:
#    data['data'][0]['node']['color'][counter] = label
#    counter = counter + 1    
#    
            
data_trace = dict(
    type='sankey',
    width = 1118,
    height = 772,
    domain = dict(
      x =  [0,1],
      y =  [0,1]
    ),
    orientation = "h",
    valueformat = ".0f",
    valuesuffix = "genes",
    node = dict(
      pad = 15,
      thickness = 15,
      line = dict(
        color = "black",
        width = 0.5
      ),
      label =  data['data'][0]['node']['label'],
      color =  data['data'][0]['node']['color']
    ),
    link = dict(
      source =  data['data'][0]['link']['source'],
      target =  data['data'][0]['link']['target'],
      value =  data['data'][0]['link']['value'],
      label =  data['data'][0]['link']['label']
  ))

layout =  dict(
    title = "Test Sankey",
    font = dict(
      size = 10
    )
)

fig = dict(data=[data_trace], layout=layout)
py.iplot(fig, validate=False)

# %%
import sankey
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
pd.options.display.max_rows=8
# %matplotlib inline

df = pd.read_csv('customers-goods.csv',sep = ',',names=['id', 'customer','good','revenue'])
sankey.sankey(left=df['customer'], right=df['good'], rightWeight=df['revenue'],
               aspect=20, colorDict=colorDict, fontsize=20,
               figure_name="customer-good")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-15-fdd6c1a78f4d> in <module>()
# ----> 1 import sankey
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
#       4 import pandas as pd
#       5 pd.options.display.max_rows=8
#
# ModuleNotFoundError: No module named 'sankey'

# %%
from ipysankeywidget import SankeyWidget
from ipywidgets import Layout
from IPython.display import (
    Image,
    SVG
)

layout = Layout(width="1000", height="600")
def sankey(margin_top=10, **value):
    """Show SankeyWidget with default values for size and margins"""
    return SankeyWidget(layout=layout,
                        margins=dict(top=margin_top, bottom=0, left=100, right=120),
                        **value)


links = [
    {'source': '2017.42', 'target': 'Total Ordered', 'value': 438, 'type': 'a'},
    {'source': '2017.44', 'target': 'Total Ordered', 'value': 27, 'type': 'a'},
    {'source': '2017.46', 'target': 'Total Ordered', 'value': 68, 'type': 'a'},
    {'source': '2017.48', 'target': 'Total Ordered', 'value': 101, 'type': 'a'},
    {'source': '2017.50', 'target': 'Total Ordered', 'value': 5, 'type': 'b'},
    {'source': 'Total Ordered', 'target': 'Abandoned', 'value': 35, 'type': 'c'},
    {'source': 'Total Ordered', 'target': 'Received', 'value': 497, 'type': 'd'},
    {'source': 'Total Ordered', 'target': 'In Production', 'value': 107, 'type': 'e'},
    {'source': 'Received', 'target': 'Build Attempted', 'value': 267, 'type': 'f'},
    {'source': 'Build Attempted', 'target': 'Verified Success', 'value': 149, 'type': 'g'},
    {'source': 'Build Attempted', 'target': 'Failures', 'value': 118, 'type': 'g'},
    {'source': 'Received', 'target': 'Not Yet Attempted', 'value': 230, 'type': 'g'},

]

#links[0]["value"] = 16
groups = [
    {'id': 'G', 'title': 'Group', 'nodes': ['C', 'D']}
]

#order = [
#    [ [   ], [   ], ['A'],[   ],[   ]   ],
#    [ [   ], [   ], ['B'],[   ],[   ]   ],
#    [ [   ], ['D'], [   ],["C"],[   ]   ],    
#    [ ['E'], ['H'], ['G'],[   ],['F']   ],
#]

#order = [
#    [ ['X'], ['Y'],['Z'] ],
#    [ [], ['A'] ],
#    [ [], ['B'] ],
#    [ ['E'], ['D'], ["C"] ],   
#    [ ['E'], ['H'], ['G'], ['F'] ],
#]

rank_sets = [
    { 'type': 'same', 'nodes': ['Abandoned','In Production','Verified Success','Failures','Not Yet Attempted'] }
]

diagram = sankey(links=links, rank_sets=rank_sets, margin_top=30)

diagram.auto_save_png('test.png')
# Out:
# SankeyWidget(layout=Layout(height='600', width='1000'), links=[{'source': '2017.42', 'target': 'Total Ordered', 'value': 438, 'type': 'a'}, {'source': '2017.44', 'target': 'Total Ordered', 'value': 27, 'type': 'a'}, {'source': '2017.46', 'target': 'Total Ordered', 'value': 68, 'type': 'a'}, {'source': '2017.48', 'target': 'Total Ordered', 'value': 101, 'type': 'a'}, {'source': '2017.50', 'target': 'Total Ordered', 'value': 5, 'type': 'b'}, {'source': 'Total Ordered', 'target': 'Abandoned', 'value': 35, 'type': 'c'}, {'source': 'Total Ordered', 'target': 'Received', 'value': 497, 'type': 'd'}, {'source': 'Total Ordered', 'target': 'In Production', 'value': 107, 'type': 'e'}, {'source': 'Received', 'target': 'Build Attempted', 'value': 267, 'type': 'f'}, {'source': 'Build Attempted', 'target': 'Verified Success', 'value': 149, 'type': 'g'}, {'source': 'Build Attempted', 'target': 'Failures', 'value': 118, 'type': 'g'}, {'source': 'Received', 'target': 'Not Yet Attempted', 'value': 230, 'type': 'g'}], margins={'top': 30, 'bottom': 0, 'left': 100, 'right': 120}, nodes=[{'id': 'Build Attempted'}, {'id': 'Not Yet Attempted'}, {'id': 'Abandoned'}, {'id': '2017.42'}, {'id': 'Total Ordered'}, {'id': 'In Production'}, {'id': '2017.48'}, {'id': '2017.50'}, {'id': '2017.46'}, {'id': 'Received'}, {'id': 'Verified Success'}, {'id': '2017.44'}, {'id': 'Failures'}], rank_sets=[{'type': 'same', 'nodes': ['Abandoned', 'In Production', 'Verified Success', 'Failures', 'Not Yet Attempted']}])
